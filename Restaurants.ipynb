# %%
# Importing and installing packages

import requests # library to handle requests 
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np # library to handle data in a vectorized manner 
import random # library for random number generation
import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

import matplotlib.pyplot as plt # plotting library
# backend for rendering plots within the browser
# %matplotlib inline 

# import k-means from clustering stage
from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
# C:\Users\adity\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
# FourSquare Log in 

CLIENT_ID = 'HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG' # your Foursquare ID
CLIENT_SECRET = 'ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN' # your Foursquare Secret
VERSION = '20210802'
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG
# CLIENT_SECRET:ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN

# %%
# New York location Co-ordinates

address = 'New York'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7127281 -74.0060152

# %%
# New York Foursquare Indian restaurants link

ny_Ind_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=40.7127281,-74.0060152&v=20210802&query=Indian Restaurant'
ny_Ind_url
#ny_Ind_results = requests.get(ny_Ind_url).json()
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=40.7127281,-74.0060152&v=20210802&query=Indian Restaurant'

# %%
# New York Foursquare French restaurants link

ny_Fre_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=40.7127281,-74.0060152&v=20210802&query=French Restaurant'
ny_Fre_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=40.7127281,-74.0060152&v=20210802&query=French Restaurant'

# %%
# New York Foursquare Japanese restaurants link

ny_Jap_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=40.7127281,-74.0060152&v=20210802&query=Japanese Restaurant'
ny_Jap_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=40.7127281,-74.0060152&v=20210802&query=Japanese Restaurant'

# %%
# New York Foursquare Spanish restaurants link

ny_Spa_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=40.7127281,-74.0060152&v=20210802&query=Spanish Restaurant'
ny_Spa_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=40.7127281,-74.0060152&v=20210802&query=Spanish Restaurant'

# %%
# New York Foursquare Chinese restaurants link

ny_Chi_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=40.7127281,-74.0060152&v=20210802&query=Chinese Restaurant'
ny_Chi_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=40.7127281,-74.0060152&v=20210802&query=Chinese Restaurant'

# %%
# New York Foursquare Italian restaurants link

ny_Ita_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=40.7127281,-74.0060152&v=20210802&query=Italian Restaurant'
ny_Ita_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=40.7127281,-74.0060152&v=20210802&query=Italian Restaurant'

# %%
# New York Indian restaurants raw data

ny_Ind_results = requests.get(ny_Ind_url).json()
ny_Ind_results
# Out:
# {'meta': {'code': 200, 'requestId': '6108cd308cd6ae317efcfcce'},
#  'response': {'venues': [{'id': '4116be80f964a520f90b1fe3',
#     'name': 'Panna II Garden Indian Restaurant',
#     'location': {'address': '93 1st Ave',
#      'crossStreet': 'btwn 5th & 6th St',
#      'lat': 40.726272990045985,
#      'lng': -73.98627301759028,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.726272990045985,
#        'lng': -73.98627301759028},
#       {'label': 'entrance', 'lat': 40.726254, 'lng': -73.986488}],
#      'distance': 2246,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['93 1st Ave (btwn 5th & 6th St)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
# ...

# %%
# New York French restaurants raw data

ny_Fre_results = requests.get(ny_Fre_url).json()
ny_Fre_results
# Out:
# {'meta': {'code': 200, 'requestId': '6108cd3b4b3384404047ce5d'},
#  'response': {'venues': [{'id': '4f32b24519836c91c7f0c696',
#     'name': 'M C Choi French Restaurant',
#     'location': {'address': '200 Church St',
#      'lat': 40.71617126464844,
#      'lng': -74.00717163085938,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71617126464844,
#        'lng': -74.00717163085938}],
#      'distance': 395,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['200 Church St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1627966779',
# ...

# %%
# New York Japanese restaurants raw data

ny_Jap_results = requests.get(ny_Jap_url).json()
ny_Jap_results
# Out:
# {'meta': {'code': 200, 'requestId': '6108cd430cbcc10bafad21d9'},
#  'response': {'venues': [{'id': '45a38e32f964a520ee401fe3',
#     'name': 'SUteiShi Japanese Restaurant',
#     'location': {'address': '24 Peck Slip',
#      'crossStreet': 'btwn Front & Water St',
#      'lat': 40.707807603285566,
#      'lng': -74.0018892288208,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707807603285566,
#        'lng': -74.0018892288208},
#       {'label': 'entrance', 'lat': 40.707755, 'lng': -74.001838}],
#      'distance': 649,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['24 Peck Slip (btwn Front & Water St)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
# ...

# %%
# New York Spanish restaurants raw data

ny_Spa_results = requests.get(ny_Spa_url).json()
ny_Spa_results
# Out:
# {'meta': {'code': 200, 'requestId': '6108cd4c93d5720bcd32d5aa'},
#  'response': {'venues': [{'id': '4b50dbe2f964a520a63527e3',
#     'name': 'Milanes Spanish Restaurant',
#     'location': {'address': '168 W 25th St',
#      'crossStreet': '7th Ave',
#      'lat': 40.745266225075866,
#      'lng': -73.99444080260349,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.745266225075866,
#        'lng': -73.99444080260349}],
#      'distance': 3751,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['168 W 25th St (7th Ave)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1be941735',
#       'name': 'Latin American Restaurant',
#       'pluralName': 'Latin American Restaurants',
#       'shortName': 'Latin American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
# ...

# %%
# New York Chinese restaurants raw data

ny_Chi_results = requests.get(ny_Chi_url).json()
ny_Chi_results
# Out:
# {'meta': {'code': 200, 'requestId': '6108cd5380edd2734e694fb1'},
#  'response': {'venues': [{'id': '58aa398b14fb41097a0cf923',
#     'name': 'Great Fortune Chinese Restaurant 聚旺茶餐廳',
#     'location': {'address': '5 Catherine St',
#      'crossStreet': 'btwn E Broadway & Chatham Sq',
#      'lat': 40.713875,
#      'lng': -73.99728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.713875,
#        'lng': -73.99728}],
#      'distance': 748,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['5 Catherine St (btwn E Broadway & Chatham Sq)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '52af3a7c3cf9994f4e043bed',
#       'name': 'Cantonese Restaurant',
#       'pluralName': 'Cantonese Restaurants',
#       'shortName': 'Cantonese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
# ...

# %%
# New York Italian restaurants raw data

ny_Ita_results = requests.get(ny_Ita_url).json()
ny_Ita_results
# Out:
# {'meta': {'code': 200, 'requestId': '6108cd5ad18fec395042ef70'},
#  'response': {'venues': [{'id': '4e4c4d28bd413c4cc66857a5',
#     'name': "Caruso's Italian Restaurant",
#     'location': {'address': '42 Broadway',
#      'lat': 40.710509099999996,
#      'lng': -74.00827615,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.710509099999996,
#        'lng': -74.00827615}],
#      'distance': 312,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['42 Broadway',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1627966810',
# ...

# %%
# New York Indian restaurants Dataframe

# assign relevant part of JSON to venues
ny_Ind_venues = ny_Ind_results['response']['venues']

# tranform venues into a dataframe
ny_Ind_dataframe = pd.json_normalize(ny_Ind_venues)
ny_Ind_dataframe.head()
# Out:
#                          id                               name  \
# 0  4116be80f964a520f90b1fe3  Panna II Garden Indian Restaurant
# 1  4c17b29b838020a1fd0de361         Bombay's Indian Restaurant
# 2  506a2625498e3c434686abbc             Asya Indian Restaurant
# 3  4d0e6159bf0c8eec2188282a                  Indian Restaurant
# 4  4f32a9c119836c91c7eda319                  Indian Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1627966769    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1627966769    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1627966769    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1627966769    False
# 4  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1627966769    False
#
#   location.address location.crossStreet  location.lat  location.lng  \
# ...

# %%
# New York French restaurants Dataframe

# assign relevant part of JSON to venues
ny_Fre_venues = ny_Fre_results['response']['venues']

# tranform venues into a dataframe
ny_Fre_dataframe = pd.json_normalize(ny_Fre_venues)
ny_Fre_dataframe.head()
# Out:
#                          id                        name  \
# 0  4f32b24519836c91c7f0c696  M C Choi French Restaurant
# 1  4f32404c19836c91c7c5204b    Andres French Restaurant
# 2  49f125dcf964a52091691fe3   O'Hara's Restaurant & Pub
# 3  568c0e32498e175822170e51         French Cheese Board
# 4  59d4dc5fe57ca67d0a64319f       The French Block Cafe
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1627966779    False
# 1  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1627966779    False
# 2  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...  v-1627966779    False
# 3  [{'id': '4bf58dd8d48988d11e951735', 'name': 'C...  v-1627966779    False
# 4  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1627966779    False
#
#    location.address  location.lat  location.lng  \
# 0     200 Church St     40.716171    -74.007172
# 1     242 W 56th St     40.765682    -73.982567
# ...

# %%
# New York Japanese restaurants Dataframe

# assign relevant part of JSON to venues
ny_Jap_venues = ny_Jap_results['response']['venues']

# tranform venues into a dataframe
ny_Jap_dataframe = pd.json_normalize(ny_Jap_venues)
ny_Jap_dataframe.head()
# Out:
#                          id                          name  \
# 0  45a38e32f964a520ee401fe3  SUteiShi Japanese Restaurant
# 1  5464f27c498e2e01c60151af     Kaede Japanese Restaurant
# 2  4e4e4c34bd4101d0d7a71f7d       Aoi Japanese Restaurant
# 3  4f326c4819836c91c7d658ff    Nagoya Japanese Restaurant
# 4  4a85b541f964a520fdfe1fe3    Tataki Japanese Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1627966787    False
# 1  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1627966787    False
# 2  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1627966787    False
# 3  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1627966787    False
# 4  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1627966787    False
#
#   location.address   location.crossStreet  location.lat  location.lng  \
# 0     24 Peck Slip  btwn Front & Water St     40.707808    -74.001889
# ...

# %%
# New York Spanish restaurants Dataframe

# assign relevant part of JSON to venues
ny_Spa_venues = ny_Spa_results['response']['venues']

# tranform venues into a dataframe
ny_Spa_dataframe = pd.json_normalize(ny_Spa_venues)
ny_Spa_dataframe.head()
# Out:
#                          id                                name  \
# 0  4b50dbe2f964a520a63527e3          Milanes Spanish Restaurant
# 1  4e4ceb86bd413c4cc66d3c0a  No. 1 Chinese & Spanish Restaurant
# 2  4c6d9c0010faa143a863ee68              M&K Spanish Restaurant
# 3  4e4ac3591f6e2d88d8bdee8f            M & K spanish restaurant
# 4  4f0c3503e4b0497598540065                  Spanish restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1be941735', 'name': 'L...  v-1627966796    False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1627966796    False
# 2  [{'id': '4bf58dd8d48988d150941735', 'name': 'S...  v-1627966796    False
# 3  [{'id': '4bf58dd8d48988d150941735', 'name': 'S...  v-1627966796    False
# 4  [{'id': '4bf58dd8d48988d150941735', 'name': 'S...  v-1627966796    False
#
#   location.address location.crossStreet  location.lat  location.lng  \
# ...

# %%
# New York Chinese restaurants Dataframe

# assign relevant part of JSON to venues
ny_Chi_venues = ny_Chi_results['response']['venues']

# tranform venues into a dataframe
ny_Chi_dataframe = pd.json_normalize(ny_Chi_venues)
ny_Chi_dataframe.head()
# Out:
#                          id                                    name  \
# 0  58aa398b14fb41097a0cf923  Great Fortune Chinese Restaurant 聚旺茶餐廳
# 1  4e4463cf52b18fcc799a9761       88 Reach House chinese restaurant
# 2  581299bb38fa2e54303f6891                Taste Chinese Restaurant
# 3  4d83993c81fdb1f7cf87eabf           Canal Best Chinese Restaurant
# 4  4b54fcddf964a520bfd627e3            Food King Chinese Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '52af3a7c3cf9994f4e043bed', 'name': 'C...  v-1627966803    False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1627966803    False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1627966803    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1627966803    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1627966803    False
#
#   location.address          location.crossStreet  location.lat  location.lng  \
# ...

# %%
# New York Italian restaurants Dataframe

# assign relevant part of JSON to venues
ny_Ita_venues = ny_Ita_results['response']['venues']

# tranform venues into a dataframe
ny_Ita_dataframe = pd.json_normalize(ny_Ita_venues)
ny_Ita_dataframe.head()
# Out:
#                          id                             name  \
# 0  4e4c4d28bd413c4cc66857a5      Caruso's Italian Restaurant
# 1  4f3232e219836c91c7bfde94  Conca Cucina Italian Restaurant
# 2  4bbf6b6430c99c74302a5511   PJ Charlton Italian Restaurant
# 3  4b76d8dbf964a520be632ee3       Pier 76 Italian Restaurant
# 4  4a7778a1f964a5209be41fe3     Carmine's Italian Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1627966810    False
# 1  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1627966810    False
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1627966810    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1627966810    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1627966810    False
#
#    location.address  location.lat  location.lng  \
# 0       42 Broadway     40.710509    -74.008276
# ...

# %%
# New York filtered Indian restaurants list

# keep only columns that include venue name, and anything that is associated with location
ny_Ind_filtered_columns = ['name', 'categories'] + [col for col in ny_Ind_dataframe.columns if col.startswith('location.')] + ['id']
ny_Ind_dataframe_filtered1 = ny_Ind_dataframe.loc[:, ny_Ind_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        ny_Ind_categories_list = row['categories']
    except:
        ny_Ind_categories_list = row['venue.categories']
        
    if len(ny_Ind_categories_list) == 0:
        return None
    else:
        return ny_Ind_categories_list[0]['name']

# filter the category for each row
ny_Ind_dataframe_filtered1['categories'] = ny_Ind_dataframe_filtered1.apply(get_category_type, axis=1)

# clean column names by keeping only last term
ny_Ind_dataframe_filtered1.columns = [column.split('.')[-1] for column in ny_Ind_dataframe_filtered1.columns]

ny_Ind_dataframe_filtered1
# Out:
#                                            name            categories  \
# 0             Panna II Garden Indian Restaurant     Indian Restaurant
# 1                    Bombay's Indian Restaurant     Indian Restaurant
# 2                        Asya Indian Restaurant     Indian Restaurant
# 3                             Indian Restaurant     Indian Restaurant
# 4                             Indian Restaurant                  Food
# 5                       Dhaka Indian Restaurant     Indian Restaurant
# 6                      Polash Indian restaurant     Indian Restaurant
# 7                   Spice Hut Indian Restaurant     Indian Restaurant
# 8                    Nepalese Indian Restaurant     Indian Restaurant
# 9                         Joy Indian Restaurant     Indian Restaurant
# 10                   S&A West Indian Restaurant  Caribbean Restaurant
# 11              Salena's West Indian Restaurant  Caribbean Restaurant
# ...

# %%
ny_Ind_dataframe_filtered = ny_Ind_dataframe_filtered1[ny_Ind_dataframe_filtered1['categories']!='Caribbean Restaurant']
ny_Ind_dataframe_filtered
# Out:
#                                      name         categories  \
# 0       Panna II Garden Indian Restaurant  Indian Restaurant
# 1              Bombay's Indian Restaurant  Indian Restaurant
# 2                  Asya Indian Restaurant  Indian Restaurant
# 3                       Indian Restaurant  Indian Restaurant
# 4                       Indian Restaurant               Food
# 5                 Dhaka Indian Restaurant  Indian Restaurant
# 6                Polash Indian restaurant  Indian Restaurant
# 7             Spice Hut Indian Restaurant  Indian Restaurant
# 8              Nepalese Indian Restaurant  Indian Restaurant
# 9                   Joy Indian Restaurant  Indian Restaurant
# 13               Kismat Indian Restaurant  Indian Restaurant
# 14                Angel Indian Restaurant  Indian Restaurant
# 15             Tazmohol Indian Restaurant  Indian Restaurant
# 16              Aanchal Indian Restaurant  Indian Restaurant
# ...

# %%
# New York filtered French restaurants list

# keep only columns that include venue name, and anything that is associated with location
ny_Fre_filtered_columns = ['name', 'categories'] + [col for col in ny_Fre_dataframe.columns if col.startswith('location.')] + ['id']
ny_Fre_dataframe_filtered1 = ny_Fre_dataframe.loc[:, ny_Fre_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        ny_Fre_categories_list = row['categories']
    except:
        ny_Fre_categories_list = row['venue.categories']
        
    if len(ny_Fre_categories_list) == 0:
        return None
    else:
        return ny_Fre_categories_list[0]['name']

# filter the category for each row
ny_Fre_dataframe_filtered1['categories'] = ny_Fre_dataframe_filtered1.apply(get_category_type, axis=1)

# clean column names by keeping only last term
ny_Fre_dataframe_filtered1.columns = [column.split('.')[-1] for column in ny_Fre_dataframe_filtered1.columns]

ny_Fre_dataframe_filtered1
# Out:
#                                           name  \
# 0                   M C Choi French Restaurant
# 1                     Andres French Restaurant
# 2                    O'Hara's Restaurant & Pub
# 3                          French Cheese Board
# 4                        The French Block Cafe
# 5                     Amore's Pizza Restaurant
# 6              Mudville Restaurant & Tap House
# 7                 TJ Byrnes Bar and Restaurant
# 8               Golden Unicorn Restaurant 麒麟金閣
# 9                              Le French Diner
# 10                               French Corner
# 11             French kiss Boudoir Photography
# 12                             French Cleaners
# 13                              French Embassy
# 14                            French Nails Spa
# 15                  Deluxe Green Bo Restaurant
# 16                                       Felix
# 17                         Arturo's Restaurant
# 18                          Waverly Restaurant
# ...

# %%
ny_Fre_dataframe_filtered2 = ny_Fre_dataframe_filtered1[ny_Fre_dataframe_filtered1['categories'] =='French Restaurant']
ny_Fre_dataframe_filtered2
# Out:
#                     name         categories         address        lat  \
# 9        Le French Diner  French Restaurant  188 Orchard St  40.722114
# 16                 Felix  French Restaurant  340 W Broadway  40.722446
# 24  PMF Pardon My French  French Restaurant    103 Avenue B  40.724891
# 25          French Roast  French Restaurant   2340 Broadway  40.787624
# 27        French Quarter  French Restaurant   102 E 25th St  40.741233
# 29          Dirty French  French Restaurant   180 Ludlow St  40.721837
#
#           lng                                     labeledLatLngs  distance  \
# 9  -73.988130  [{'label': 'display', 'lat': 40.722113618193, ...      1835
# 16 -74.003818  [{'label': 'display', 'lat': 40.72244564074977...      1097
# 24 -73.981383  [{'label': 'display', 'lat': 40.72489136863149...      2480
# 25 -73.976944  [{'label': 'display', 'lat': 40.78762393478021...      8690
# 27 -73.985264  [{'label': 'display', 'lat': 40.741233, 'lng':...      3623
# ...

# %%
ny_Fre_dataframe_filtered3 = ny_Fre_dataframe_filtered1[ny_Fre_dataframe_filtered1['categories'] =='Food'] 
ny_Fre_dataframe_filtered3
# Out:
#                          name categories        address        lat        lng  \
# 0  M C Choi French Restaurant       Food  200 Church St  40.716171 -74.007172
# 1    Andres French Restaurant       Food  242 W 56th St  40.765682 -73.982567
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 40.71617126464844...       395      10013  US
# 1  [{'label': 'display', 'lat': 40.765682, 'lng':...      6217      10019  US
#
#        city state        country  \
# 0  New York    NY  United States
# 1  New York    NY  United States
#
#                                     formattedAddress crossStreet neighborhood  \
# 0  [200 Church St, New York, NY 10013, United Sta...         NaN          NaN
# 1  [242 W 56th St, New York, NY 10019, United Sta...         NaN          NaN
#
#                          id
# 0  4f32b24519836c91c7f0c696
# 1  4f32404c19836c91c7c5204b

# %%
ny_Fre_dataframe_filtered4 = ny_Fre_dataframe_filtered1[ny_Fre_dataframe_filtered1['categories'] =='Café']
ny_Fre_dataframe_filtered4
# Out:
#                     name categories           address        lat       lng  \
# 4  The French Block Cafe       Café  201 Lafayette St  40.721411 -73.99779
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 4  [{'label': 'display', 'lat': 40.721411, 'lng':...      1189      10012  US
#
#        city state        country  \
# 4  New York    NY  United States
#
#                                     formattedAddress crossStreet neighborhood  \
# 4  [201 Lafayette St, New York, NY 10012, United ...         NaN          NaN
#
#                          id
# 4  59d4dc5fe57ca67d0a64319f

# %%
# New York French restaurants list
ny_Fre_dataframe_filtered = (ny_Fre_dataframe_filtered2, ny_Fre_dataframe_filtered3, ny_Fre_dataframe_filtered4)
ny_Fre_rest_filtered = pd.concat(ny_Fre_dataframe_filtered)
ny_Fre_rest_filtered
# Out:
#                           name         categories           address  \
# 9              Le French Diner  French Restaurant    188 Orchard St
# 16                       Felix  French Restaurant    340 W Broadway
# 24        PMF Pardon My French  French Restaurant      103 Avenue B
# 25                French Roast  French Restaurant     2340 Broadway
# 27              French Quarter  French Restaurant     102 E 25th St
# 29                Dirty French  French Restaurant     180 Ludlow St
# 0   M C Choi French Restaurant               Food     200 Church St
# 1     Andres French Restaurant               Food     242 W 56th St
# 4        The French Block Cafe               Café  201 Lafayette St
#
#           lat        lng                                     labeledLatLngs  \
# 9   40.722114 -73.988130  [{'label': 'display', 'lat': 40.722113618193, ...
# 16  40.722446 -74.003818  [{'label': 'display', 'lat': 40.72244564074977...
# ...

# %%
# New York filtered Japanese restaurants list

# keep only columns that include venue name, and anything that is associated with location
ny_Jap_filtered_columns = ['name', 'categories'] + [col for col in ny_Jap_dataframe.columns if col.startswith('location.')] + ['id']
ny_Jap_dataframe_filtered = ny_Jap_dataframe.loc[:, ny_Jap_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        ny_Jap_categories_list = row['categories']
    except:
        ny_Jap_categories_list = row['venue.categories']
        
    if len(ny_Jap_categories_list) == 0:
        return None
    else:
        return ny_Jap_categories_list[0]['name']

# filter the category for each row
ny_Jap_dataframe_filtered['categories'] = ny_Jap_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
ny_Jap_dataframe_filtered.columns = [column.split('.')[-1] for column in ny_Jap_dataframe_filtered.columns]

ny_Jap_dataframe_filtered
# Out:
#                                   name           categories  \
# 0         SUteiShi Japanese Restaurant     Sushi Restaurant
# 1            Kaede Japanese Restaurant  Japanese Restaurant
# 2              Aoi Japanese Restaurant  Japanese Restaurant
# 3           Nagoya Japanese Restaurant                 Food
# 4           Tataki Japanese Restaurant  Japanese Restaurant
# 5           Nagoya Japanese Restaurant  Japanese Restaurant
# 6           Kokura Japanese Restaurant  Japanese Restaurant
# 7             Wave Japanese Restaurant  Japanese Restaurant
# 8           Narita Japanese Restaurant  Japanese Restaurant
# 9             Yama Japanese Restaurant     Sushi Restaurant
# 10         Okinawa Japanese Restaurant  Japanese Restaurant
# 11             Edo Japanese Restaurant     Sushi Restaurant
# 12          Win 49 Japanese Restaurant  Japanese Restaurant
# 13            Yuka Japanese Restaurant     Sushi Restaurant
# 14           Yoshi Japanese Restaurant  Japanese Restaurant
# ...

# %%
# New York filtered Spanish restaurants list

# keep only columns that include venue name, and anything that is associated with location
ny_Spa_filtered_columns = ['name', 'categories'] + [col for col in ny_Spa_dataframe.columns if col.startswith('location.')] + ['id']
ny_Spa_dataframe_filtered1 = ny_Spa_dataframe.loc[:, ny_Spa_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        ny_Spa_categories_list = row['categories']
    except:
        ny_Spa_categories_list = row['venue.categories']
        
    if len(ny_Spa_categories_list) == 0:
        return None
    else:
        return ny_Spa_categories_list[0]['name']

# filter the category for each row
ny_Spa_dataframe_filtered1['categories'] = ny_Spa_dataframe_filtered1.apply(get_category_type, axis=1)

# clean column names by keeping only last term
ny_Spa_dataframe_filtered1.columns = [column.split('.')[-1] for column in ny_Spa_dataframe_filtered1.columns]

ny_Spa_dataframe_filtered1
# Out:
#                                                  name  \
# 0                          Milanes Spanish Restaurant
# 1                  No. 1 Chinese & Spanish Restaurant
# 2                              M&K Spanish Restaurant
# 3                            M & K spanish restaurant
# 4                                  Spanish restaurant
# 5                          Stanley Spanish Restaurant
# 6                          Three  Spanish  Restaurant
# 7                         Tropical Spanish Restaurant
# 8                The New Millenium Spanish Restaurant
# 9                          Toribio Spanish Restaurant
# 10                           M & K Spanish Restaurant
# 11                                 Spanish Restaurant
# 12                         Caridad Spanish Restaurant
# 13                          O'Hara's Restaurant & Pub
# 14                           Amore's Pizza Restaurant
# 15                    Mudville Restaurant & Tap House
# ...

# %%
ny_Spa_dataframe_filtered2 = ny_Spa_dataframe_filtered1[ny_Spa_dataframe_filtered1['categories'] == 'Spanish Restaurant']
ny_Spa_dataframe_filtered2
# Out:
#                                     name          categories          address  \
# 2                 M&K Spanish Restaurant  Spanish Restaurant       190 Bay St
# 3               M & K spanish restaurant  Spanish Restaurant  56 Richmond Ter
# 4                     Spanish restaurant  Spanish Restaurant              NaN
# 6             Three  Spanish  Restaurant  Spanish Restaurant   384 E 188th St
# 8   The New Millenium Spanish Restaurant  Spanish Restaurant   1558 Fulton St
# 9             Toribio Spanish Restaurant  Spanish Restaurant              NaN
# 10              M & K Spanish Restaurant  Spanish Restaurant    Richmond Road
# 12            Caridad Spanish Restaurant  Spanish Restaurant              NaN
# 16                         Spanish Diner  Spanish Restaurant  10 Hudson Yards
#
#           crossStreet        lat        lng  \
# 2                 NaN  40.637543 -74.076827
# 3                 NaN  40.644112 -74.076950
# 4                 NaN  40.888698 -73.857186
# ...

# %%
ny_Spa_dataframe_filtered3 = ny_Spa_dataframe_filtered1[ny_Spa_dataframe_filtered1['categories'] == 'Latin American Restaurant']
ny_Spa_dataframe_filtered3
# Out:
#                           name                 categories        address  \
# 0   Milanes Spanish Restaurant  Latin American Restaurant  168 W 25th St
# 7  Tropical Spanish Restaurant  Latin American Restaurant  3771 Broadway
#
#   crossStreet        lat        lng  \
# 0     7th Ave  40.745266 -73.994441
# 7       157th  40.833988 -73.945202
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 40.74526622507586...      3751      10001  US
# 7  [{'label': 'display', 'lat': 40.83398781790348...     14439      10032  US
#
#        city state        country  \
# 0  New York    NY  United States
# 7  New York    NY  United States
#
#                                     formattedAddress neighborhood  \
# 0  [168 W 25th St (7th Ave), New York, NY 10001, ...          NaN
# 7  [3771 Broadway (157th), New York, NY 10032, Un...          NaN
#
#                          id
# 0  4b50dbe2f964a520a63527e3
# ...

# %%
ny_Spa_dataframe_filtered4 = ny_Spa_dataframe_filtered1[ny_Spa_dataframe_filtered1['categories'] == 'South American Restaurant']
ny_Spa_dataframe_filtered4
# Out:
#                   name                 categories address crossStreet  \
# 11  Spanish Restaurant  South American Restaurant     NaN         NaN
#
#           lat        lng                                     labeledLatLngs  \
# 11  40.795248 -74.483475  [{'label': 'display', 'lat': 40.7952479, 'lng'...
#
#     distance postalCode  cc        city state        country  \
# 11     41296      07960  US  Morristown    NJ  United States
#
#                          formattedAddress neighborhood  \
# 11  [Morristown, NJ 07960, United States]          NaN
#
#                           id
# 11  4cd2f5a53e0c8cfa0bf51a12

# %%
ny_Spa_dataframe_filtered5 = ny_Spa_dataframe_filtered1[ny_Spa_dataframe_filtered1['categories'] == 'Tapas Restaurant']
ny_Spa_dataframe_filtered5
# Out:
#                                                  name        categories  \
# 24  Spanish Pavillion Restaurant Tapas Bar & Outdo...  Tapas Restaurant
#
#             address crossStreet        lat        lng  \
# 24  31 Harrison Ave  Dey Street  40.745337 -74.163404
#
#                                        labeledLatLngs  distance postalCode  \
# 24  [{'label': 'display', 'lat': 40.74533710725015...     13764      07029
#
#     cc      city state        country  \
# 24  US  Harrison    NJ  United States
#
#                                      formattedAddress neighborhood  \
# 24  [31 Harrison Ave (Dey Street), Harrison, NJ 07...          NaN
#
#                           id
# 24  4b9e9c64f964a520aaf336e3

# %%
ny_Spa_dataframe_filtered6 = ny_Spa_dataframe_filtered1[ny_Spa_dataframe_filtered1['categories'] == 'Food Truck']
ny_Spa_dataframe_filtered6
# Out:
#                            name  categories                       address  \
# 28  Spanish Lady Breakfast Cart  Food Truck  Between 23rd and 24th Street
#
#    crossStreet        lat        lng  \
# 28     1st Ave  40.737413 -73.978288
#
#                                        labeledLatLngs  distance postalCode  \
# 28  [{'label': 'display', 'lat': 40.73741278617314...      3608        NaN
#
#     cc      city state        country  \
# 28  US  New York    NY  United States
#
#                                      formattedAddress neighborhood  \
# 28  [Between 23rd and 24th Street (1st Ave), New Y...          NaN
#
#                           id
# 28  4e9ebca702d576b6554db063

# %%
ny_Spa_dataframe_filtered7 = ny_Spa_dataframe_filtered1[ny_Spa_dataframe_filtered1['categories'] == 'Breakfast Spot']
ny_Spa_dataframe_filtered7
# Out:
#                          name      categories          address  \
# 5  Stanley Spanish Restaurant  Breakfast Spot  675 Stanley Ave
#
#       crossStreet        lat        lng  \
# 5  Hendrix Street  40.659529 -73.883985
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 5  [{'label': 'display', 'lat': 40.659529, 'lng':...     11881      11207  US
#
#        city state        country  \
# 5  Brooklyn    NY  United States
#
#                                     formattedAddress neighborhood  \
# 5  [675 Stanley Ave (Hendrix Street), Brooklyn, N...          NaN
#
#                          id
# 5  4f327effe4b0f41ae8a34150

# %%
# New York Spanish restaurants list
ny_Spa_dataframe_filtered = (ny_Spa_dataframe_filtered2, ny_Spa_dataframe_filtered3, ny_Spa_dataframe_filtered4, ny_Spa_dataframe_filtered5, ny_Spa_dataframe_filtered6, ny_Spa_dataframe_filtered7)
ny_Spa_rest_filtered = pd.concat(ny_Spa_dataframe_filtered)
ny_Spa_rest_filtered
# Out:
#                                                  name  \
# 2                              M&K Spanish Restaurant
# 3                            M & K spanish restaurant
# 4                                  Spanish restaurant
# 6                          Three  Spanish  Restaurant
# 8                The New Millenium Spanish Restaurant
# 9                          Toribio Spanish Restaurant
# 10                           M & K Spanish Restaurant
# 12                         Caridad Spanish Restaurant
# 16                                      Spanish Diner
# 0                          Milanes Spanish Restaurant
# 7                         Tropical Spanish Restaurant
# 11                                 Spanish Restaurant
# 24  Spanish Pavillion Restaurant Tapas Bar & Outdo...
# 28                        Spanish Lady Breakfast Cart
# 5                          Stanley Spanish Restaurant
#
#                    categories                       address  \
# ...

# %%
# New York filtered Chinese restaurants list

# keep only columns that include venue name, and anything that is associated with location
ny_Chi_filtered_columns = ['name', 'categories'] + [col for col in ny_Chi_dataframe.columns if col.startswith('location.')] + ['id']
ny_Chi_dataframe_filtered = ny_Chi_dataframe.loc[:, ny_Chi_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        ny_Chi_categories_list = row['categories']
    except:
        ny_Chi_categories_list = row['venue.categories']
        
    if len(ny_Chi_categories_list) == 0:
        return None
    else:
        return ny_Chi_categories_list[0]['name']

# filter the category for each row
ny_Chi_dataframe_filtered['categories'] = ny_Chi_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
ny_Chi_dataframe_filtered.columns = [column.split('.')[-1] for column in ny_Chi_dataframe_filtered.columns]

ny_Chi_dataframe_filtered
# Out:
#                                       name            categories  \
# 0   Great Fortune Chinese Restaurant 聚旺茶餐廳  Cantonese Restaurant
# 1        88 Reach House chinese restaurant    Chinese Restaurant
# 2                 Taste Chinese Restaurant    Chinese Restaurant
# 3            Canal Best Chinese Restaurant    Chinese Restaurant
# 4             Food King Chinese Restaurant    Chinese Restaurant
# 5           Dragon Gate Chinese Restaurant    Chinese Restaurant
# 6              Downtown Chinese Restaurant                  Food
# 7                 Ann's Chinese Restaurant      Asian Restaurant
# 8          Malasia-Thai-Chinese Restaurant      Asian Restaurant
# 9            Marco Polo Chinese Restaurant    Chinese Restaurant
# 10      Fu Zhou An Ping Chinese Restaurant      Asian Restaurant
# 11               Wenger Chinese Restaurant    Chinese Restaurant
# 12       P and C Garden Chinese Restaurant                  Food
# ...

# %%
# New York filtered Italian restaurants list

# keep only columns that include venue name, and anything that is associated with location
ny_Ita_filtered_columns = ['name', 'categories'] + [col for col in ny_Ita_dataframe.columns if col.startswith('location.')] + ['id']
ny_Ita_dataframe_filtered = ny_Ita_dataframe.loc[:, ny_Ita_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        ny_Ita_categories_list = row['categories']
    except:
        ny_Ita_categories_list = row['venue.categories']
        
    if len(ny_Ita_categories_list) == 0:
        return None
    else:
        return ny_Ita_categories_list[0]['name']

# filter the category for each row
ny_Ita_dataframe_filtered['categories'] = ny_Ita_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
ny_Ita_dataframe_filtered.columns = [column.split('.')[-1] for column in ny_Ita_dataframe_filtered.columns]

ny_Ita_dataframe_filtered
# Out:
#                                              name          categories  \
# 0                     Caruso's Italian Restaurant  Italian Restaurant
# 1                 Conca Cucina Italian Restaurant                Food
# 2                  PJ Charlton Italian Restaurant  Italian Restaurant
# 3                      Pier 76 Italian Restaurant  Italian Restaurant
# 4                    Carmine's Italian Restaurant  Italian Restaurant
# 5    Alex's Italian Restaurant & Brick Oven Pizza  Italian Restaurant
# 6              Nonna's Pizza & Italian Restaurant         Pizza Place
# 7              Palermo Pizza & Italian Restaurant         Pizza Place
# 8             Chazz Palminteri Italian Restaurant  Italian Restaurant
# 9             Gianni's Pizza & Italian Restaurant         Pizza Place
# 10          Mimi's Italian Restaurant & Piano Bar  Italian Restaurant
# 11  Casanova Family Italian Restaurant & Pizzeria         Pizza Place
# ...

# %%
# New York restaurants list
ny_dataframe_filtered1 = (ny_Ind_dataframe_filtered, ny_Fre_rest_filtered, ny_Jap_dataframe_filtered, ny_Spa_rest_filtered, ny_Chi_dataframe_filtered, ny_Ita_dataframe_filtered)
ny_rest_filt = pd.concat(ny_dataframe_filtered1)
ny_rest_filt
# Out:
#                                  name          categories           address  \
# 0   Panna II Garden Indian Restaurant   Indian Restaurant        93 1st Ave
# 1          Bombay's Indian Restaurant   Indian Restaurant       60 Pearl St
# 2              Asya Indian Restaurant   Indian Restaurant       46 Henry St
# 3                   Indian Restaurant   Indian Restaurant     369 Broome St
# 4                   Indian Restaurant                Food       338 9th Ave
# ..                                ...                 ...               ...
# 25          Pepe's Italian Restaurant  Italian Restaurant  117 Watchung Ave
# 26         Dante's Italian Restaurant  Italian Restaurant     373 Broad Ave
# 27           Sam's Italian Restaurant  Italian Restaurant       127 Main St
# 28         Da Nina Italian Restaurant  Italian Restaurant   1 Lafayette Ave
# 29         Claudio Italian Restaurant         Pizza Place       344 8th Ave
#
#           crossStreet        lat        lng  \
# ...

# %%
# New York categorised restaurants map

ny_venues_map = folium.Map(location=[40.7127281, -74.0060152], zoom_start=13) # generate map in new york

# add a black circle marker to represent the Statue of Liberty
folium.features.CircleMarker(
    [latitude, longitude],
    color='black',
    popup='Statue of Liberty',
    fill = True,
    fill_color = 'black',
    fill_opacity = 0.6
).add_to(ny_venues_map)

# add the Indian restaurants as Orange circle markers
for lat, lng, label in zip(ny_Ind_dataframe_filtered.lat, ny_Ind_dataframe_filtered.lng, ny_Ind_dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        color='orange',
        popup=label,
        fill = True,
        fill_color='orange',
        fill_opacity=0.6
    ).add_to(ny_venues_map)   
    
# add the French restaurants as brown circle markers
for lat, lng, label in zip(ny_Fre_rest_filtered.lat, ny_Fre_rest_filtered.lng, ny_Fre_rest_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        color='brown',
        popup=label,
        fill = True,
        fill_color='brown',
        fill_opacity=0.6
    ).add_to(ny_venues_map)   
    
# add the Japanese restaurants as yellow circle markers
for lat, lng, label in zip(ny_Jap_dataframe_filtered.lat, ny_Jap_dataframe_filtered.lng, ny_Jap_dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        color='yellow',
        popup=label,
        fill = True,
        fill_color='yellow',
        fill_opacity=0.6
    ).add_to(ny_venues_map)   
    
# add the Spanish restaurants as green circle markers
for lat, lng, label in zip(ny_Spa_rest_filtered.lat, ny_Spa_rest_filtered.lng, ny_Spa_rest_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(ny_venues_map)   

# add the Chinese restaurants as red circle markers
for lat, lng, label in zip(ny_Chi_dataframe_filtered.lat, ny_Chi_dataframe_filtered.lng, ny_Chi_dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(ny_venues_map)
    
# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(ny_Ita_dataframe_filtered.lat, ny_Ita_dataframe_filtered.lng, ny_Ita_dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(ny_venues_map)    
            
# display map
ny_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ny_pop_df = pd.read_excel('D:/Demographic Data.xlsx')

# %%
ny_pop_df
# Out:
#          Coumty          Black         Asian        Native    Hawaiian   \
# 0        Albany   37256.564573  11733.180765    746.225342     0.000000
# 1      Allegany     500.076993    462.248291    143.933599     0.000000
# 2         Bronx  609427.874489  49371.559440  17783.105906  7460.807317
# 3        Broome    7955.209676   6556.426815    398.250941     0.000000
# 4   Cattaraugus     992.733534    442.149681   1954.619415     0.000000
# ..          ...            ...           ...           ...          ...
# 57   Washington    2006.156893    221.928662    124.162732     0.000000
# 58        Wayne    2937.716694    505.735955    276.559241     0.000000
# 59  Westchester  144299.479202  53248.389361   3641.549266   871.253020
# 60      Wyoming    2329.010259    193.533483    122.728550    21.713513
# 61        Yates     165.689287     72.741638      0.000000     0.000000
#
#          Hispanic          White        lat        lng
# ...

# %%
ny_pop_df1 = pd.read_excel('D:/Demographic Data.xlsx')
ny_pop_df1
# Out:
#           Black         Asian         Native     Hawaiian       Hispanic  \
# 0  3.448761e+06  1.313777e+06  105975.552695  16901.875768  3.197771e+06
#
#           White        lat        lng
# 0  1.119357e+07  40.712728 -74.006015

# %%
#!pip install geopandas==0.3.0
#!pip install pyshp==1.2.10
#!pip install shapely==1.6.3

# !conda install -c conda-forge geopandas==0.3.0 --yes
# !conda install -c conda-forge pyshp==1.2.10 --yes
# !conda install -c conda-forge shapely==1.6.3 --yes

import requests # library to handle requests

# %%
ny_pop_url = 'https://cocl.us/new_york_dataset'
ny_pop_url
ny_pop_results = requests.get(ny_pop_url).json()
ny_pop_results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-01d9077014e4> in <module>
#       1 ny_pop_url = 'https://cocl.us/new_york_dataset'
#       2 ny_pop_url
# ----> 3 ny_pop_results = requests.get(ny_pop_url).json()
#       4 ny_pop_results
#
# NameError: name 'requests' is not defined

# %%
# denominations in the json file
import json
communities_geo = r'new york-communities.geojson'

# open the json file - json.load() methods returns a python dictionary
with open(communities_geo) as communities_file:
    communities_json = json.load(communities_file)
    
# we loop through the dictionary to obtain the name of the communities in the json file
denominations_json = []
for index in range(len(communities_json['features'])):
    denominations_json.append(communities_json['features'][index]['properties']['name'])
    
denominations_json
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-029398205a91> in <module>
#       4
#       5 # open the json file - json.load() methods returns a python dictionary
# ----> 6 with open(communities_geo) as communities_file:
#       7     communities_json = json.load(communities_file)
#       8
#
# FileNotFoundError: [Errno 2] No such file or directory: 'new york-communities.geojson'

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
#   File "<ipython-input-3-e6db3a9ea572>", line 1
#     -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
#           ^
# SyntaxError: invalid syntax

# %%
# New York Population concentration map

ny_pop_map = folium.Map(location=[42.6000783, -73.9662388], zoom_start=13) # generate map in Albany
ny_pop_map = folium.Map(location=[42.2506243, -78.0330619], zoom_start=13) # generate map in Allegany
ny_pop_map = folium.Map(location=[40.8501002, -73.8662464], zoom_start=13) # generate map in Bronx
ny_pop_map = folium.Map(location=[42.2506314, -75.8329722], zoom_start=13) # generate map in Broome

# add a black circle marker to represent the the Black Population 
for lat, lng, label in zip(ny_pop_df.lat, ny_pop_df.lng, ny_pop_df.Coumty):
    folium.features.CircleMarker(
        [lat, lng],
        color='black',
        popup=label,
        fill = True,
        fill_color='black',
        fill_opacity=0.6
    ).add_to(ny_pop_map)   

# display map
ny_pop_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Tokyo location Co-ordinates

address = 'Tokyo'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 35.6828387 139.7594549

# %%
# Tokyo Foursquare Indian restaurants link

tok_Ind_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=35.6828387,139.7594549&v=20210518&query=Indian Restaurant'
tok_Ind_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=35.6828387,139.7594549&v=20210518&query=Indian Restaurant'

# %%
# Tokyo Foursquare French restaurants link

tok_Fre_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=35.6828387,139.7594549&v=20210518&query=French Restaurant'
tok_Fre_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=35.6828387,139.7594549&v=20210518&query=French Restaurant'

# %%
# Tokyo Foursquare Japanese restaurants link

tok_Jap_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=35.6828387,139.7594549&v=20210518&query=Japanese Restaurant'
tok_Jap_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=35.6828387,139.7594549&v=20210518&query=Japanese Restaurant'

# %%
# Tokyo Foursquare Spanish restaurants link

tok_Spa_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=35.6828387,139.7594549&v=20210518&query=Spanish Restaurant'
tok_Spa_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=35.6828387,139.7594549&v=20210518&query=Spanish Restaurant'

# %%
# Tokyo Foursquare Chinese restaurants link

tok_Chi_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=35.6828387,139.7594549&v=20210518&query=Chinese Restaurant'
tok_Chi_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=35.6828387,139.7594549&v=20210518&query=Chinese Restaurant'

# %%
# Tokyo Foursquare Italian restaurants link

tok_Ita_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=35.6828387,139.7594549&v=20210518&query=Italian Restaurant'
tok_Ita_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=35.6828387,139.7594549&v=20210518&query=Italian Restaurant'

# %%
# Tokyo Indian restaurants raw data

tok_Ind_results = requests.get(tok_Ind_url).json()
tok_Ind_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a3dc277d9b925ff43e81cc'},
#  'response': {'venues': [{'id': '4e30d44c62e1deac123d6060',
#     'name': "Indian Restaurant & Bar Downtown B's",
#     'location': {'address': '六本木3-4-2',
#      'crossStreet': 'コープ野村 1F',
#      'lat': 35.66509468189221,
#      'lng': 139.73686784334336,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.66509468189221,
#        'lng': 139.73686784334336}],
#      'distance': 2841,
#      'postalCode': '106-0032',
#      'cc': 'JP',
#      'city': '東京',
#      'state': '東京都',
#      'country': '日本',
#      'formattedAddress': ['六本木3-4-2 (コープ野村 1F)', '港区, 東京都', '106-0032', '日本']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
# ...

# %%
# Tokyo French restaurants raw data

tok_Fre_results = requests.get(tok_Fre_url).json()
tok_Fre_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a3dc32cdb1de3462970c44'},
#  'response': {'venues': [{'id': '51865e62498ea00e97168a56',
#     'name': 'French Restaurant Bonheur (フレンチレストラン ボヌール)',
#     'location': {'address': '1-1-2',
#      'crossStreet': '花井',
#      'lat': 35.945723219612276,
#      'lng': 139.8666234593013,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.945723219612276,
#        'lng': 139.8666234593013}],
#      'distance': 30821,
#      'cc': 'JP',
#      'city': '野田市',
#      'state': '千葉県',
#      'country': '日本',
#      'formattedAddress': ['1-1-2 (花井)', '野田市, 千葉県', '日本']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621351474',
#     'hasPerk': False},
# ...

# %%
# Tokyo Japanese restaurants raw data

tok_Jap_results = requests.get(tok_Jap_url).json()
tok_Jap_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a3dc3dbfd44c277f6f555a'},
#  'response': {'venues': [{'id': '4ba6d53cf964a520527239e3',
#     'name': 'Japanese Restaurant ZIGI (日本料理 時宜)',
#     'location': {'address': '有明3-1-5',
#      'crossStreet': '東京ベイコート倶楽部 24F',
#      'lat': 35.62878098518967,
#      'lng': 139.7869116067886,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.62878098518967,
#        'lng': 139.7869116067886}],
#      'distance': 6509,
#      'postalCode': '135-0063',
#      'cc': 'JP',
#      'city': '東京',
#      'state': '東京都',
#      'country': '日本',
#      'formattedAddress': ['有明3-1-5 (東京ベイコート倶楽部 24F)',
#       '江東区, 東京都',
#       '135-0063',
#       '日本']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
# ...

# %%
# Tokyo Spanish restaurants raw data

tok_Spa_results = requests.get(tok_Spa_url).json()
tok_Spa_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a3dc468e03f54a6730332d'},
#  'response': {'venues': [{'id': '4bc7d9b88b7c9c74fe5637cf',
#     'name': 'SPANISH BAR SoL SEVILLA',
#     'location': {'address': '築地2-14-2',
#      'crossStreet': 'セリコ東銀座ビル 1F',
#      'lat': 35.667782087960255,
#      'lng': 139.7707054244246,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.667782087960255,
#        'lng': 139.7707054244246}],
#      'distance': 1960,
#      'postalCode': '112-0011',
#      'cc': 'JP',
#      'city': '東京',
#      'state': '東京都',
#      'country': '日本',
#      'formattedAddress': ['築地2-14-2 (セリコ東銀座ビル 1F)',
#       '中央区, 東京都',
#       '112-0011',
#       '日本']},
#     'categories': [{'id': '4bf58dd8d48988d150941735',
#       'name': 'Spanish Restaurant',
#       'pluralName': 'Spanish Restaurants',
#       'shortName': 'Spanish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#        'suffix': '.png'},
#       'primary': True}],
# ...

# %%
# Tokyo Chinese restaurants raw data

tok_Chi_results = requests.get(tok_Chi_url).json()
tok_Chi_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a3dc503c06365b452cd912'},
#  'response': {'venues': [{'id': '5d22b75fa18cd50030f3f8f2',
#     'name': 'Chinese Restaurant 大申',
#     'location': {'address': '日本橋人形町1-4-13',
#      'lat': 35.685574,
#      'lng': 139.78176,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.685574,
#        'lng': 139.78176}],
#      'distance': 2039,
#      'postalCode': '103-0013',
#      'cc': 'JP',
#      'city': '東京',
#      'state': '東京都',
#      'country': '日本',
#      'formattedAddress': ['日本橋人形町1-4-13', '中央区, 東京都', '103-0013', '日本']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621351504',
#     'hasPerk': False},
#    {'id': '4e0b07c4149563b079c2dcfb',
# ...

# %%
# Tokyo Italian restaurants raw data

tok_Ita_results = requests.get(tok_Ita_url).json()
tok_Ita_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a3dc5b4dee530b0726f6d5'},
#  'response': {'venues': [{'id': '60549b67d6b26c180c00a2af',
#     'name': 'Aman Tokyo Arva Italian Restaurant',
#     'location': {'address': 'The Otemachi Tower',
#      'lat': 35.685554,
#      'lng': 139.765371,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.685554,
#        'lng': 139.765371}],
#      'distance': 614,
#      'postalCode': '100-0004',
#      'cc': 'JP',
#      'city': '東京',
#      'state': '東京都',
#      'country': '日本',
#      'formattedAddress': ['The Otemachi Tower',
#       '千代田区, 東京都',
#       '100-0004',
#       '日本']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621351515',
#     'hasPerk': False},
# ...

# %%
# Tokyo Indian restaurants Dataframe

# assign relevant part of JSON to venues
tok_Ind_venues = tok_Ind_results['response']['venues']

# tranform venues into a dataframe
tok_Ind_dataframe = pd.json_normalize(tok_Ind_venues)
tok_Ind_dataframe.head()
# Out:
#                          id                                     name  \
# 0  4e30d44c62e1deac123d6060     Indian Restaurant & Bar Downtown B's
# 1  560df7d2498e72653c5b7395                   Indian Restaurant Asha
# 2  52be672b498e6ccdabd1d860              Chandrama Indian Restaurant
# 3  4dcbbb15ae60f2054414642b                  Kyber Indian Restaurant
# 4  4b6a491cf964a520cbd02be3  Indian Restaurant Avatar (インド料理 アヴァタール)
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621351463    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621351463    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621351463    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621351463    False
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621351463    False
#
#   location.address location.crossStreet  location.lat  location.lng  \
# ...

# %%
# Tokyo French restaurants Dataframe

# assign relevant part of JSON to venues
tok_Fre_venues = tok_Fre_results['response']['venues']

# tranform venues into a dataframe
tok_Fre_dataframe = pd.json_normalize(tok_Fre_venues)
tok_Fre_dataframe.head()
# Out:
#                          id                                        name  \
# 0  51865e62498ea00e97168a56  French Restaurant Bonheur (フレンチレストラン ボヌール)
# 1  5749c571498e40ec7393307d                French restaurant Maximilian
# 2  520f724711d25409bcfeeece                       French Restaurant 千代田
# 3  5655ac92498ef88692fd7744                    The French Toast Factory
# 4  4dccf2dfd4c065592f59165d                           French-Bar Refuge
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621351474    False
# 1  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621351474    False
# 2  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621351474    False
# 3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1621351474    False
# 4  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621351474    False
#
# ...

# %%
# Tokyo Japanese restaurants Dataframe

# assign relevant part of JSON to venues
tok_Jap_venues = tok_Jap_results['response']['venues']

# tranform venues into a dataframe
tok_Jap_dataframe = pd.json_normalize(tok_Jap_venues)
tok_Jap_dataframe.head()
# Out:
#                          id                                name  \
# 0  4ba6d53cf964a520527239e3  Japanese Restaurant ZIGI (日本料理 時宜)
# 1  5b699056340a58002c4bb42e   Halal Japanese Restaurant Origami
# 2  57a6800d498e3ebd845a0b26         Origine Japanese Restaurant
# 3  53981c55498e599773914a86       Monteroza Japanese Restaurant
# 4  4bb5fa152f70c9b6bdb38430            JAPANESE DINING KEYAKI 欅
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621351485    False
# 1  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621351485    False
# 2  [{'id': '52e81612bcbc57f1066b79f4', 'name': 'B...  v-1621351485    False
# 3  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621351485    False
# 4  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1621351485    False
#
#                              location.address location.crossStreet  \
# ...

# %%
# Tokyo Spanish restaurants Dataframe

# assign relevant part of JSON to venues
tok_Spa_venues = tok_Spa_results['response']['venues']

# tranform venues into a dataframe
tok_Spa_dataframe = pd.json_normalize(tok_Spa_venues)
tok_Spa_dataframe.head()
# Out:
#                          id                                  name  \
# 0  4bc7d9b88b7c9c74fe5637cf               SPANISH BAR SoL SEVILLA
# 1  5386a5c8498ee4b654b4ce58  Tokyo Athlete Restaurant (東京アスリート食堂)
# 2  4c982d72f419a09363dc6d88      Bar&Restaurant FRANZUYA (フランズーヤ)
# 3  4d4a279a83eda1cdfae2afb1       Restaurant Rosette (レストラン ロゼット)
# 4  55482b82498ead95e681b34b                MOTIF RESTAURANT & BAR
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d150941735', 'name': 'S...  v-1621351494    False
# 1  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621351494    False
# 2  [{'id': '4bf58dd8d48988d123941735', 'name': 'W...  v-1621351494    False
# 3  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621351494    False
# 4  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1621351494    False
#
#   location.address  location.crossStreet  location.lat  location.lng  \
# ...

# %%
# Tokyo Chinese restaurants Dataframe

# assign relevant part of JSON to venues
tok_Chi_venues = tok_Chi_results['response']['venues']

# tranform venues into a dataframe
tok_Chi_dataframe = pd.json_normalize(tok_Chi_venues)
tok_Chi_dataframe.head()
# Out:
#                          id                        name  \
# 0  5d22b75fa18cd50030f3f8f2       Chinese Restaurant 大申
# 1  4e0b07c4149563b079c2dcfb  Kozanro chinese restaurant
# 2  5450d0d7498e36edc7305f4c    Keien Chinese Restaurant
# 3  57c81333498ea48b744dbca9                 You-en (遊猿)
# 4  5191bfa5498eeb6c4cff944a    CHINESE RESTAURANT 三田 坐祥
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621351504    False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621351504    False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621351504    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621351504    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621351504    False
#
#   location.address  location.lat  location.lng  \
# 0     日本橋人形町1-4-13     35.685574    139.781760
# 1  Akasaka 7 chome     35.673575    139.762887
# ...

# %%
# Tokyo Italian restaurants Dataframe

# assign relevant part of JSON to venues
tok_Ita_venues = tok_Ita_results['response']['venues']

# tranform venues into a dataframe
tok_Ita_dataframe = pd.json_normalize(tok_Ita_venues)
tok_Ita_dataframe.head()
# Out:
#                          id                                    name  \
# 0  60549b67d6b26c180c00a2af      Aman Tokyo Arva Italian Restaurant
# 1  57247fe5498e225a56df9c19                  360 Italian Restaurant
# 2  57d53081cd10e323f1c3b47b       American-Italian Restaurant JOLIE
# 3  501caf46e4b0944fada98e34  Italian Restaurant & Bar GOHAN Machida
# 4  548d0b93498e5c3a98733234               Italian Restaurant MOTORA
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1621351515    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621351515    False
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621351515    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621351515    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621351515    False
#
#      location.address  location.lat  location.lng  \
# ...

# %%
# Tokya filtered Indian restaurants list

# keep only columns that include venue name, and anything that is associated with location
tok_Ind_filtered_columns = ['name', 'categories'] + [col for col in tok_Ind_dataframe.columns if col.startswith('location.')] + ['id']
tok_Ind_dataframe_filtered = tok_Ind_dataframe.loc[:, tok_Ind_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        tok_Ind_categories_list = row['categories']
    except:
        tok_Ind_categories_list = row['venue.categories']
        
    if len(tok_Ind_categories_list) == 0:
        return None
    else:
        return tok_Ind_categories_list[0]['name']

# filter the category for each row
tok_Ind_dataframe_filtered['categories'] = tok_Ind_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
tok_Ind_dataframe_filtered.columns = [column.split('.')[-1] for column in tok_Ind_dataframe_filtered.columns]

tok_Ind_dataframe_filtered
# Out:
#                                                name  \
# 0              Indian Restaurant & Bar Downtown B's
# 1                            Indian Restaurant Asha
# 2                       Chandrama Indian Restaurant
# 3                           Kyber Indian Restaurant
# 4           Indian Restaurant Avatar (インド料理 アヴァタール)
# 5   Indian Restaurant & Bar Munal (インドレストラン&バー ムナル)
# 6              Indian Restaurant MUNA (インドレストラン ムナ)
# 7                       INDIAN RESTAURANT LAXMI ラスミ
# 8               Nepali Indian restaurant & bar Sewa
# 9                    Hira Indian Restaurant and Bar
# 10           Indian Restaurant LIMU インディアン レストラン リム
# 11                           HOLI Indian Restaurant
# 12   INDIAN RESTAURANT Spice Cafe (本格インド料理 スパイスカフェ)
# 13                       Indian Restaurant NEW MINA
# 14                   Indian Restaurant Phulbari 橋場店
# 15             Indian Restaurant & Bar Ueno Kitchen
# 16                          Indian Restaurant Yujin
# ...

# %%
# Tokya filtered French restaurants list

# keep only columns that include venue name, and anything that is associated with location
tok_Fre_filtered_columns = ['name', 'categories'] + [col for col in tok_Fre_dataframe.columns if col.startswith('location.')] + ['id']
tok_Fre_dataframe_filtered = tok_Fre_dataframe.loc[:, tok_Fre_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        tok_Fre_categories_list = row['categories']
    except:
        tok_Fre_categories_list = row['venue.categories']
        
    if len(tok_Fre_categories_list) == 0:
        return None
    else:
        return tok_Fre_categories_list[0]['name']

# filter the category for each row
tok_Fre_dataframe_filtered['categories'] = tok_Fre_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
tok_Fre_dataframe_filtered.columns = [column.split('.')[-1] for column in tok_Fre_dataframe_filtered.columns]

tok_Fre_dataframe_filtered
# Out:
#                                                name                categories  \
# 0        French Restaurant Bonheur (フレンチレストラン ボヌール)         French Restaurant
# 1                      French restaurant Maximilian         French Restaurant
# 2                             French Restaurant 千代田         French Restaurant
# 3                          The French Toast Factory                      Café
# 4                                 French-Bar Refuge         French Restaurant
# 5              Tokyo Athlete Restaurant (東京アスリート食堂)       Japanese Restaurant
# 6                             French-Bar Refuge 神楽坂         French Restaurant
# 7                   Restaurant Rosette (レストラン ロゼット)         French Restaurant
# 8                  Bar&Restaurant FRANZUYA (フランズーヤ)                  Wine Bar
# 9                    The French Kitchen (フレンチ キッチン)         French Restaurant
# 10                           MOTIF RESTAURANT & BAR                Restaurant
# ...

# %%
# Tokya filtered Japanese restaurants list

# keep only columns that include venue name, and anything that is associated with location
tok_Jap_filtered_columns = ['name', 'categories'] + [col for col in tok_Jap_dataframe.columns if col.startswith('location.')] + ['id']
tok_Jap_dataframe_filtered = tok_Jap_dataframe.loc[:, tok_Jap_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        tok_Jap_categories_list = row['categories']
    except:
        tok_Jap_categories_list = row['venue.categories']
        
    if len(tok_Jap_categories_list) == 0:
        return None
    else:
        return tok_Jap_categories_list[0]['name']

# filter the category for each row
tok_Jap_dataframe_filtered['categories'] = tok_Jap_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
tok_Jap_dataframe_filtered.columns = [column.split('.')[-1] for column in tok_Jap_dataframe_filtered.columns]

tok_Jap_dataframe_filtered
# Out:
#                                                  name  \
# 0                  Japanese Restaurant ZIGI (日本料理 時宜)
# 1                   Halal Japanese Restaurant Origami
# 2                         Origine Japanese Restaurant
# 3                       Monteroza Japanese Restaurant
# 4                            JAPANESE DINING KEYAKI 欅
# 5                Tokyo Athlete Restaurant (東京アスリート食堂)
# 6                           Japanese Sake Dining 夢酒知花
# 7                          Japanese Spice Curry Wacca
# 8                    Bar&Restaurant FRANZUYA (フランズーヤ)
# 9                     Restaurant Rosette (レストラン ロゼット)
# 10                             Japanese Cape Cod Cafe
# 11                             MOTIF RESTAURANT & BAR
# 12                                  Liga (スペインバル・リーガ)
# 13            The Restaurant by AMAN (ザ･レストラン by アマン)
# 14                         HiKaRi Cafe&Restaurant 銀座店
# 15                                   Restaurant ベラージュ
# ...

# %%
# Tokya filtered Spanish restaurants list

# keep only columns that include venue name, and anything that is associated with location
tok_Spa_filtered_columns = ['name', 'categories'] + [col for col in tok_Spa_dataframe.columns if col.startswith('location.')] + ['id']
tok_Spa_dataframe_filtered = tok_Spa_dataframe.loc[:, tok_Spa_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        tok_Spa_categories_list = row['categories']
    except:
        tok_Spa_categories_list = row['venue.categories']
        
    if len(tok_Spa_categories_list) == 0:
        return None
    else:
        return tok_Spa_categories_list[0]['name']

# filter the category for each row
tok_Spa_dataframe_filtered['categories'] = tok_Spa_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
tok_Spa_dataframe_filtered.columns = [column.split('.')[-1] for column in tok_Spa_dataframe_filtered.columns]

tok_Spa_dataframe_filtered
# Out:
#                                                  name  \
# 0                             SPANISH BAR SoL SEVILLA
# 1                Tokyo Athlete Restaurant (東京アスリート食堂)
# 2                    Bar&Restaurant FRANZUYA (フランズーヤ)
# 3                     Restaurant Rosette (レストラン ロゼット)
# 4                              MOTIF RESTAURANT & BAR
# 5             The Restaurant by AMAN (ザ･レストラン by アマン)
# 6                                 Spanish Bar Cazuela
# 7                          HiKaRi Cafe&Restaurant 銀座店
# 8                                    Restaurant ベラージュ
# 9                Tokyo Athlete Restaurant (東京アスリート食堂)
# 10               GREEN TEA RESTAURANT 1899 OCHANOMIZU
# 11                      Modern Catalan Spanish Bikini
# 12                        Cafe＆Restaurant Bar Colette
# 13                       Restaurant Latin (レストラン ラタン)
# 14               Restaurant Stockholm (レストラン ストックホルム)
# 15                Restaurant MASA UEKI (レストラン マサ ウエキ)
# ...

# %%
# Tokya filtered Chinese restaurants list

# keep only columns that include venue name, and anything that is associated with location
tok_Chi_filtered_columns = ['name', 'categories'] + [col for col in tok_Chi_dataframe.columns if col.startswith('location.')] + ['id']
tok_Chi_dataframe_filtered = tok_Chi_dataframe.loc[:, tok_Chi_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        tok_Chi_categories_list = row['categories']
    except:
        tok_Chi_categories_list = row['venue.categories']
        
    if len(tok_Chi_categories_list) == 0:
        return None
    else:
        return tok_Chi_categories_list[0]['name']

# filter the category for each row
tok_Chi_dataframe_filtered['categories'] = tok_Chi_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
tok_Chi_dataframe_filtered.columns = [column.split('.')[-1] for column in tok_Chi_dataframe_filtered.columns]

tok_Chi_dataframe_filtered
# Out:
#                                              name           categories  \
# 0                           Chinese Restaurant 大申   Chinese Restaurant
# 1                      Kozanro chinese restaurant   Chinese Restaurant
# 2                        Keien Chinese Restaurant   Chinese Restaurant
# 3                                     You-en (遊猿)   Chinese Restaurant
# 4                        CHINESE RESTAURANT 三田 坐祥   Chinese Restaurant
# 5              Chinese Restaurant Chafoon (チャフーン)  Szechuan Restaurant
# 6                            chinese restaurant 漢   Chinese Restaurant
# 7                        Chinese Restaurant Sunny   Chinese Restaurant
# 8                       Kohine Chinese Restaurant   Chinese Restaurant
# 9                        Keien Chinese Restaurant   Chinese Restaurant
# 10                    CAFE & CHINESE RESTAURANT 蓮   Chinese Restaurant
# 11                        Chinese Restaurant masa   Chinese Restaurant
# ...

# %%
# Tokya filtered Italian restaurants list

# keep only columns that include venue name, and anything that is associated with location
tok_Ita_filtered_columns = ['name', 'categories'] + [col for col in tok_Ita_dataframe.columns if col.startswith('location.')] + ['id']
tok_Ita_dataframe_filtered = tok_Ita_dataframe.loc[:, tok_Ita_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        tok_Ita_categories_list = row['categories']
    except:
        tok_Ita_categories_list = row['venue.categories']
        
    if len(tok_Ita_categories_list) == 0:
        return None
    else:
        return tok_Ita_categories_list[0]['name']

# filter the category for each row
tok_Ita_dataframe_filtered['categories'] = tok_Ita_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
tok_Ita_dataframe_filtered.columns = [column.split('.')[-1] for column in tok_Ita_dataframe_filtered.columns]

tok_Ita_dataframe_filtered
# Out:
#                                        name                categories  \
# 0        Aman Tokyo Arva Italian Restaurant                Restaurant
# 1                    360 Italian Restaurant        Italian Restaurant
# 2         American-Italian Restaurant JOLIE        Italian Restaurant
# 3    Italian Restaurant & Bar GOHAN Machida        Italian Restaurant
# 4                 Italian Restaurant MOTORA        Italian Restaurant
# 5            ITALIAN RESTAURANT Terra cotta        Italian Restaurant
# 6               J-Italian Restaurant & Cafe        Italian Restaurant
# 7             Trattoria, Italian Restaurant        Italian Restaurant
# 8                 Italian Restaurant Amalfi        Italian Restaurant
# 9                      Italian Town (イタリア街)              Neighborhood
# 10     Tokyo Athlete Restaurant (東京アスリート食堂)       Japanese Restaurant
# 11                         Italian Bar OTTO                       Bar
# ...

# %%
# NTokyo restaurants list
tok_dataframe_filt = (tok_Ind_dataframe_filtered, tok_Fre_dataframe_filtered, tok_Jap_dataframe_filtered, tok_Spa_dataframe_filtered, tok_Chi_dataframe_filtered, tok_Ita_dataframe_filtered)
tok_rest_filt = pd.concat(tok_dataframe_filt)
tok_rest_filt
# Out:
#                                        name           categories  \
# 0      Indian Restaurant & Bar Downtown B's    Indian Restaurant
# 1                    Indian Restaurant Asha    Indian Restaurant
# 2               Chandrama Indian Restaurant    Indian Restaurant
# 3                   Kyber Indian Restaurant    Indian Restaurant
# 4   Indian Restaurant Avatar (インド料理 アヴァタール)    Indian Restaurant
# ..                                      ...                  ...
# 25    Goumet Doctor ITALIAN (グルメドクター イタリアン)   Italian Restaurant
# 26                  Due Italian (ドゥエ イタリアン)     Ramen Restaurant
# 27     Tokyo Athlete Restaurant (東京アスリート食堂)  Japanese Restaurant
# 28     GREEN TEA RESTAURANT 1899 OCHANOMIZU             Tea Room
# 29         ITALIAN BAR MILAN (イタリアンバール ミラン)   Italian Restaurant
#
#          address      crossStreet        lat         lng  \
# 0       六本木3-4-2         コープ野村 1F  35.665095  139.736868
# 1            NaN              NaN  35.692576  139.757484
# ...

# %%
# London location Co-ordinates

address = 'London'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 51.5073219 -0.1276474

# %%
# London Foursquare Indian restaurants link

lon_Ind_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=51.5073219,-0.1276474&v=20210518&query=Indian Restaurant'
lon_Ind_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=51.5073219,-0.1276474&v=20210518&query=Indian Restaurant'

# %%
# London Foursquare French restaurants link

lon_Fre_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=51.5073219,-0.1276474&v=20210518&query=French Restaurant'
lon_Fre_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=51.5073219,-0.1276474&v=20210518&query=French Restaurant'

# %%
# London Foursquare Japanese restaurants link

lon_Jap_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=51.5073219,-0.1276474&v=20210518&query=Japanese Restaurant'
lon_Jap_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=51.5073219,-0.1276474&v=20210518&query=Japanese Restaurant'

# %%
# London Foursquare Spanish restaurants link

lon_Spa_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=51.5073219,-0.1276474&v=20210518&query=Spanish Restaurant'
lon_Spa_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=51.5073219,-0.1276474&v=20210518&query=Spanish Restaurant'

# %%
# London Foursquare Chinese restaurants link

lon_Chi_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=51.5073219,-0.1276474&v=20210518&query=Chinese Restaurant'
lon_Chi_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=51.5073219,-0.1276474&v=20210518&query=Chinese Restaurant'

# %%
# London Foursquare Italian restaurants link

lon_Ita_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=51.5073219,-0.1276474&v=20210518&query=Italian Restaurant'
lon_Ita_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=51.5073219,-0.1276474&v=20210518&query=Italian Restaurant'

# %%
# London Indian restaurants raw data

lon_Ind_results = requests.get(lon_Ind_url).json()
lon_Ind_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a3855b13054a759b3325b0'},
#  'response': {'venues': [{'id': '59832ed68496ca5052ea37bc',
#     'name': 'Shapur Indian Restaurant',
#     'location': {'address': '149 Strand',
#      'lat': 51.51150689149121,
#      'lng': -0.11841416358947753,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51150689149121,
#        'lng': -0.11841416358947753}],
#      'distance': 791,
#      'postalCode': 'WC2R 1JA',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['149 Strand',
#       'London',
#       'Greater London',
#       'WC2R 1JA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
# ...

# %%
# London French restaurants raw data

lon_Fre_results = requests.get(lon_Fre_url).json()
lon_Fre_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a38551281cad21dab0f428'},
#  'response': {'venues': [{'id': '504b8cc2e4b08bf9e9d9ac9c',
#     'name': "Otto's French Restaurant",
#     'location': {'address': '182 Grays Inn Rd',
#      'lat': 51.52286668054787,
#      'lng': -0.11429820215742446,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52286668054787,
#        'lng': -0.11429820215742446}],
#      'distance': 1962,
#      'postalCode': 'WC1X 8EW',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['182 Grays Inn Rd',
#       'London',
#       'Greater London',
#       'WC1X 8EW',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
# ...

# %%
# London Japanese restaurants raw data

lon_Jap_results = requests.get(lon_Jap_url).json()
lon_Jap_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a3856cbfd44c277fa6b94d'},
#  'response': {'venues': [{'id': '4fa838f4e4b04ca63ab059ca',
#     'name': 'LIKO Korean & Japanese Restaurant',
#     'location': {'lat': 51.51106133630649,
#      'lng': -0.13144520182822858,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51106133630649,
#        'lng': -0.13144520182822858}],
#      'distance': 492,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621329260',
#     'hasPerk': False},
#    {'id': '4b48b2f2f964a5203e5326e3',
#     'name': 'Okawari Japanese Restaurant',
# ...

# %%
# London Spanish restaurants raw data

lon_Spa_results = requests.get(lon_Spa_url).json()
lon_Spa_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a38565e868fb6e3573135e'},
#  'response': {'venues': [{'id': '5b619132d03360002c66b9e4',
#     'name': 'India India Restaurant',
#     'location': {'address': '8 Crane Court',
#      'lat': 51.50719323477933,
#      'lng': -0.12786626815795898,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50719323477933,
#        'lng': -0.12786626815795898}],
#      'distance': 20,
#      'postalCode': 'EC4A 2EJ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['8 Crane Court',
#       'London',
#       'Greater London',
#       'EC4A 2EJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
# ...

# %%
# London Chinese restaurants raw data

lon_Chi_results = requests.get(lon_Chi_url).json()
lon_Chi_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a3f0fccfc8b572b766a037'},
#  'response': {'venues': [{'id': '4c39bcafedba9521cf6cd625',
#     'name': 'New Loon Fung Chinese Restaurant',
#     'location': {'address': '42-44 Gerrard St',
#      'lat': 51.51203891754673,
#      'lng': -0.13037107224776798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51203891754673,
#        'lng': -0.13037107224776798}],
#      'distance': 557,
#      'postalCode': 'W1D 5QG',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['42-44 Gerrard St',
#       'London',
#       'Greater London',
#       'W1D 5QG',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
# ...

# %%
# London Italian restaurants raw data

lon_Ita_results = requests.get(lon_Ita_url).json()
lon_Ita_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a385804dee530b075e231d'},
#  'response': {'venues': [{'id': '5fca3197e348ca6f709f9f53',
#     'name': 'Prezzo Italian Restaurant London Northumberland Avenue',
#     'location': {'address': '31-32 Northumberland Ave',
#      'crossStreet': 'Grand Buildings',
#      'lat': 51.50751,
#      'lng': -0.12674,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50751,
#        'lng': -0.12674}],
#      'distance': 66,
#      'postalCode': 'WC2N 5BW',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['31-32 Northumberland Ave (Grand Buildings)',
#       'London',
#       'WC2N 5BW',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
# ...

# %%
# London Indian restaurants Dataframe

# assign relevant part of JSON to venues
lon_Ind_venues = lon_Ind_results['response']['venues']

# tranform venues into a dataframe
lon_Ind_dataframe = pd.json_normalize(lon_Ind_venues)
lon_Ind_dataframe.head()
# Out:
#                          id                        name  \
# 0  59832ed68496ca5052ea37bc    Shapur Indian Restaurant
# 1  4cae3b30c5e6a1cd3037c3f6     Truly Indian Restaurant
# 2  4f36e716e4b0fc67a8b07d36      Shad Indian Restaurant
# 3  4e84c25302d59a0afa25d1fe  Paradise Indian Restaurant
# 4  5694d061498e9653be39803a           Indian Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621329244    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621329244    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621329244    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621329244    False
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621329244    False
#
#       location.address  location.lat  location.lng  \
# 0           149 Strand     51.511507     -0.118414
# 1  borough high street     51.503994     -0.091137
# ...

# %%
# London French restaurants Dataframe

# assign relevant part of JSON to venues
lon_Fre_venues = lon_Fre_results['response']['venues']

# tranform venues into a dataframe
lon_Fre_dataframe = pd.json_normalize(lon_Fre_venues)
lon_Fre_dataframe.head()
# Out:
#                          id                                         name  \
# 0  504b8cc2e4b08bf9e9d9ac9c                     Otto's French Restaurant
# 1  4f906160e4b094de9bbc8e98     L'Absinthe French Restaurant & Wine Shop
# 2  4b7ae82ff964a52039452fe3                 The Little French Restaurant
# 3  5b619132d03360002c66b9e4                       India India Restaurant
# 4  4d650a7989238cfac03f9436  French Chamber of Commerce in Great Britain
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621329363    False
# 1  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621329363    False
# 2  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621329363    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621329363    False
# 4  [{'id': '4bf58dd8d48988d12c951735', 'name': 'E...  v-1621329363    False
#
#    location.address  location.lat  location.lng  \
# ...

# %%
# London Japanese restaurants Dataframe

# assign relevant part of JSON to venues
lon_Jap_venues = lon_Jap_results['response']['venues']

# tranform venues into a dataframe
lon_Jap_dataframe = pd.json_normalize(lon_Jap_venues)
lon_Jap_dataframe.head()
# Out:
#                          id                               name  \
# 0  4fa838f4e4b04ca63ab059ca  LIKO Korean & Japanese Restaurant
# 1  4b48b2f2f964a5203e5326e3        Okawari Japanese Restaurant
# 2  59ce9d03a9fe123f1c751edc         Hannah Japanese Restaurant
# 3  52fcc603498e20586146fb92           Hana Japanese Restaurant
# 4  4dd5811d45ddced82057d490         Hakura Japanese Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...  v-1621329260    False
# 1  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621329260    False
# 2  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621329260    False
# 3  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621329260    False
# 4  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621329260    False
#
#    location.lat  location.lng  \
# 0     51.511061     -0.131445
# 1     51.511496     -0.130500
# 2     51.501374     -0.118479
# ...

# %%
# London Spanish restaurants Dataframe

# assign relevant part of JSON to venues
lon_Spa_venues = lon_Spa_results['response']['venues']

# tranform venues into a dataframe
lon_Spa_dataframe = pd.json_normalize(lon_Spa_venues)
lon_Spa_dataframe.head()
# Out:
#                          id  \
# 0  5b619132d03360002c66b9e4
# 1  527ceafd11d2b7c4ccaef013
# 2  4dd37b6bb3adbe1ab5f60119
# 3  4e43c086483b132669cd084a
# 4  5fca3197e348ca6f709f9f53
#
#                                                 name  \
# 0                             India India Restaurant
# 1                                    The Spanish Lab
# 2                                  Spanish Consulate
# 3                                   Spanish Flavours
# 4  Prezzo Italian Restaurant London Northumberlan...
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621329253    False
# 1  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1621329253    False
# 2  [{'id': '4bf58dd8d48988d12c951735', 'name': 'E...  v-1621329253    False
# 3  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1621329253    False
# 4  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1621329253    False
#
# ...

# %%
# London Chinese restaurants Dataframe

# assign relevant part of JSON to venues
lon_Chi_venues = lon_Chi_results['response']['venues']

# tranform venues into a dataframe
lon_Chi_dataframe = pd.json_normalize(lon_Chi_venues)
lon_Chi_dataframe.head()
# Out:
#                          id                               name  \
# 0  4c39bcafedba9521cf6cd625   New Loon Fung Chinese Restaurant
# 1  5ce42f8cfdb9a7002ce3bb01            Ruyi Chinese Restaurant
# 2  4b673969f964a5205d422be3      Friendship Chinese Restaurant
# 3  55d79303498ed8dc0c88529d  The Old Street Chinese Restaurant
# 4  4ad9e4abf964a520a81b21e3         Mayling Chinese Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621356796    False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621356796    False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621356796    False
# 3  [{'id': '52af3b773cf9994f4e043c03', 'name': 'S...  v-1621356796    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621356796    False
#
#        location.address  location.lat  location.lng  \
# 0      42-44 Gerrard St     51.512039     -0.130371
# ...

# %%
# London Italian restaurants Dataframe

# assign relevant part of JSON to venues
lon_Ita_venues = lon_Ita_results['response']['venues']

# tranform venues into a dataframe
lon_Ita_dataframe = pd.json_normalize(lon_Ita_venues)
lon_Ita_dataframe.head()
# Out:
#                          id  \
# 0  5fca3197e348ca6f709f9f53
# 1  4c62d713ec94a5932e3d2aca
# 2  5b266200066332001c011f5e
# 3  4d10b844c3dc370465f63a74
# 4  506729cde4b0cdb22fe75372
#
#                                                 name  \
# 0  Prezzo Italian Restaurant London Northumberlan...
# 1   Prezzo Italian Restaurant London St Martins Lane
# 2                           Vespa Italian Restaurant
# 3                          Borgia Italian Restaurant
# 4     Amici Italian Restaurant, Courtyard & Wine Bar
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1621329281    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621329281    False
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621329281    False
# 3                                                 []  v-1621329281    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621329281    False
#
# ...

# %%
# London filtered Indian restaurants list

# keep only columns that include venue name, and anything that is associated with location
lon_Ind_filtered_columns = ['name', 'categories'] + [col for col in lon_Ind_dataframe.columns if col.startswith('location.')] + ['id']
lon_Ind_dataframe_filtered = lon_Ind_dataframe.loc[:, lon_Ind_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        lon_Ind_categories_list = row['categories']
    except:
        lon_Ind_categories_list = row['venue.categories']
        
    if len(lon_Ind_categories_list) == 0:
        return None
    else:
        return lon_Ind_categories_list[0]['name']

# filter the category for each row
lon_Ind_dataframe_filtered['categories'] = lon_Ind_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
lon_Ind_dataframe_filtered.columns = [column.split('.')[-1] for column in lon_Ind_dataframe_filtered.columns]

lon_Ind_dataframe_filtered
# Out:
#                                  name            categories  \
# 0            Shapur Indian Restaurant     Indian Restaurant
# 1             Truly Indian Restaurant     Indian Restaurant
# 2              Shad Indian Restaurant     Indian Restaurant
# 3          Paradise Indian Restaurant     Indian Restaurant
# 4                   Indian Restaurant     Indian Restaurant
# 5       Nazmins Indian Restaurant Ltd     Indian Restaurant
# 6         Mayflower Indian Restaurant     Indian Restaurant
# 7             Muhib Indian Restaurant     Indian Restaurant
# 8   OYO Vii Hotel & Indian Restaurant                 Hotel
# 9            Spices Indian Restaurant     Indian Restaurant
# 10       The Bengal Indian Restaurant     Indian Restaurant
# 11         Maharaja Indian Restaurant     Indian Restaurant
# 12         Shahmoon Indian Restaurant     Indian Restaurant
# 13          Queen's Indian Restaurant     Indian Restaurant
# 14           Masala Indian Restaurant     Indian Restaurant
# ...

# %%
# London filtered French restaurants list

# keep only columns that include venue name, and anything that is associated with location
lon_Fre_filtered_columns = ['name', 'categories'] + [col for col in lon_Fre_dataframe.columns if col.startswith('location.')] + ['id']
lon_Fre_dataframe_filtered = lon_Fre_dataframe.loc[:, lon_Fre_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        lon_Fre_categories_list = row['categories']
    except:
        lon_Fre_categories_list = row['venue.categories']
        
    if len(lon_Fre_categories_list) == 0:
        return None
    else:
        return lon_Fre_categories_list[0]['name']

# filter the category for each row
lon_Fre_dataframe_filtered['categories'] = lon_Fre_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
lon_Fre_dataframe_filtered.columns = [column.split('.')[-1] for column in lon_Fre_dataframe_filtered.columns]

lon_Fre_dataframe_filtered
# Out:
#                                                  name            categories  \
# 0                            Otto's French Restaurant     French Restaurant
# 1            L'Absinthe French Restaurant & Wine Shop     French Restaurant
# 2                        The Little French Restaurant     French Restaurant
# 3                              India India Restaurant     Indian Restaurant
# 4         French Chamber of Commerce in Great Britain   Embassy / Consulate
# 5                                        French House                   Pub
# 6   Prezzo Italian Restaurant London Northumberlan...            Restaurant
# 7                                   French Connection        Clothing Store
# 8                             French Trade Commission   Government Building
# 9                                         French Sole        Clothing Store
# 10                                  Khan's Restaurant     Indian Restaurant
# ...

# %%
# London filtered Japanese restaurants list

# keep only columns that include venue name, and anything that is associated with location
lon_Jap_filtered_columns = ['name', 'categories'] + [col for col in lon_Jap_dataframe.columns if col.startswith('location.')] + ['id']
lon_Jap_dataframe_filtered = lon_Jap_dataframe.loc[:, lon_Jap_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        lon_Jap_categories_list = row['categories']
    except:
        lon_Jap_categories_list = row['venue.categories']
        
    if len(lon_Jap_categories_list) == 0:
        return None
    else:
        return lon_Jap_categories_list[0]['name']

# filter the category for each row
lon_Jap_dataframe_filtered['categories'] = lon_Jap_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
lon_Jap_dataframe_filtered.columns = [column.split('.')[-1] for column in lon_Jap_dataframe_filtered.columns]

lon_Jap_dataframe_filtered
# Out:
#                                                  name            categories  \
# 0                   LIKO Korean & Japanese Restaurant     Korean Restaurant
# 1                         Okawari Japanese Restaurant   Japanese Restaurant
# 2                          Hannah Japanese Restaurant   Japanese Restaurant
# 3                            Hana Japanese Restaurant   Japanese Restaurant
# 4                          Hakura Japanese Restaurant   Japanese Restaurant
# 5                           Aburi Japanese Restaurant   Japanese Restaurant
# 6                            Kami Japanese Restaurant      Sushi Restaurant
# 7                            TAKE Japanese Restaurant   Japanese Restaurant
# 8                            Hana Japanese Restaurant   Japanese Restaurant
# 9                          Yuhoki Japanese Restaurant                  None
# 10                          Akira Japanese Restaurant   Japanese Restaurant
# ...

# %%
# London filtered Spanish restaurants list

# keep only columns that include venue name, and anything that is associated with location
lon_Spa_filtered_columns = ['name', 'categories'] + [col for col in lon_Spa_dataframe.columns if col.startswith('location.')] + ['id']
lon_Spa_dataframe_filtered = lon_Spa_dataframe.loc[:, lon_Spa_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        lon_Spa_categories_list = row['categories']
    except:
        lon_Spa_categories_list = row['venue.categories']
        
    if len(lon_Spa_categories_list) == 0:
        return None
    else:
        return lon_Spa_categories_list[0]['name']

# filter the category for each row
lon_Spa_dataframe_filtered['categories'] = lon_Spa_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
lon_Spa_dataframe_filtered.columns = [column.split('.')[-1] for column in lon_Spa_dataframe_filtered.columns]

lon_Spa_dataframe_filtered
# Out:
#                                                  name  \
# 0                              India India Restaurant
# 1                                     The Spanish Lab
# 2                                   Spanish Consulate
# 3                                    Spanish Flavours
# 4   Prezzo Italian Restaurant London Northumberlan...
# 5                                    spanish callejon
# 6                         Spanish tapas bar & kitchen
# 7                                   Khan's Restaurant
# 8   Bartolme Bermejo - Master Of The Spanish Renai...
# 9                            Sapori Café & Restaurant
# 10                                   Spanish flavours
# 11                                  Bill's Restaurant
# 12                         Shanghai Nights Restaurant
# 13                                 Madhu's Restaurant
# 14               Cafe, Restaurant and Bar consultant
# 15                 The Smith Square Café & Restaurant
# ...

# %%
# London filtered Chinese restaurants list

# keep only columns that include venue name, and anything that is associated with location
lon_Chi_filtered_columns = ['name', 'categories'] + [col for col in lon_Chi_dataframe.columns if col.startswith('location.')] + ['id']
lon_Chi_dataframe_filtered = lon_Chi_dataframe.loc[:, lon_Chi_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        lon_Chi_categories_list = row['categories']
    except:
        lon_Chi_categories_list = row['venue.categories']
        
    if len(lon_Chi_categories_list) == 0:
        return None
    else:
        return lon_Chi_categories_list[0]['name']

# filter the category for each row
lon_Chi_dataframe_filtered['categories'] = lon_Chi_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
lon_Chi_dataframe_filtered.columns = [column.split('.')[-1] for column in lon_Chi_dataframe_filtered.columns]

lon_Chi_dataframe_filtered
# Out:
#                                       name           categories  \
# 0         New Loon Fung Chinese Restaurant   Chinese Restaurant
# 1                  Ruyi Chinese Restaurant   Chinese Restaurant
# 2            Friendship Chinese Restaurant   Chinese Restaurant
# 3        The Old Street Chinese Restaurant  Szechuan Restaurant
# 4               Mayling Chinese Restaurant   Chinese Restaurant
# 5                       Chinese Restaurant   Chinese Restaurant
# 6        齐聚一堂中餐馆Reunion Chinese Restaurant   Chinese Restaurant
# 7             Lucky Dog Chinese Restaurant   Chinese Restaurant
# 8               Hanbury Chinese Restaurant   Chinese Restaurant
# 9   Lagenda Malaysian & Chinese Restaurant   Chinese Restaurant
# 10       Nell Gwynn Chinese Restaurant 薈賓樓   Chinese Restaurant
# 11        一三八 Woodgreen Chinese restaurant   Chinese Restaurant
# 12       Forever Autumn Chinese Restaurant                 None
# 13          Water House Chinese Restaurant  Szechuan Restaurant
# ...

# %%
# London filtered Italian restaurants list

# keep only columns that include venue name, and anything that is associated with location
lon_Ita_filtered_columns = ['name', 'categories'] + [col for col in lon_Ita_dataframe.columns if col.startswith('location.')] + ['id']
lon_Ita_dataframe_filtered = lon_Ita_dataframe.loc[:, lon_Ita_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        lon_Ita_categories_list = row['categories']
    except:
        lon_Ita_categories_list = row['venue.categories']
        
    if len(lon_Ita_categories_list) == 0:
        return None
    else:
        return lon_Ita_categories_list[0]['name']

# filter the category for each row
lon_Ita_dataframe_filtered['categories'] = lon_Ita_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
lon_Ita_dataframe_filtered.columns = [column.split('.')[-1] for column in lon_Ita_dataframe_filtered.columns]

lon_Ita_dataframe_filtered
# Out:
#                                                  name          categories  \
# 0   Prezzo Italian Restaurant London Northumberlan...          Restaurant
# 1    Prezzo Italian Restaurant London St Martins Lane  Italian Restaurant
# 2                            Vespa Italian Restaurant  Italian Restaurant
# 3                           Borgia Italian Restaurant                None
# 4      Amici Italian Restaurant, Courtyard & Wine Bar  Italian Restaurant
# 5   Prezzo Italian Restaurant London New Oxford St...          Restaurant
# 6                         Colosseo Italian Restaurant  Italian Restaurant
# 7                         Sophie’s Italian Restaurant  Italian Restaurant
# 8              Il Gusto Italian Restaurant Paddington  Italian Restaurant
# 9       Prezzo Italian Restaurant North Audley Street          Restaurant
# 10                             500 Italian Restaurant  Italian Restaurant
# 11                          Domo94 Italian Restaurant  Italian Restaurant
# ...

# %%
# London restaurants list
lon_dataframe_filt = (lon_Ind_dataframe_filtered, lon_Fre_dataframe_filtered,  lon_Jap_dataframe_filtered, lon_Spa_dataframe_filtered, lon_Chi_dataframe_filtered, lon_Ita_dataframe_filtered)
lon_rest_filt = pd.concat(lon_dataframe_filt)
lon_rest_filt
# Out:
#                                         name          categories  \
# 0                   Shapur Indian Restaurant   Indian Restaurant
# 1                    Truly Indian Restaurant   Indian Restaurant
# 2                     Shad Indian Restaurant   Indian Restaurant
# 3                 Paradise Indian Restaurant   Indian Restaurant
# 4                          Indian Restaurant   Indian Restaurant
# ..                                       ...                 ...
# 25        Marco's Italian Restaurant and Bar          Restaurant
# 26  Prezzo Italian Restaurant South Woodford  Italian Restaurant
# 27          Prezzo Italian Restaurant Harrow          Restaurant
# 28              Serrafino Italian Restaurant  Italian Restaurant
# 29        Prezzo Italian Restaurant Stanmore          Restaurant
#
#                                            address        lat       lng  \
# 0                                       149 Strand  51.511507 -0.118414
# ...

# %%
# Shanghai location Co-ordinates

address = 'Shanghai'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 31.2322758 121.4692071

# %%
# Shanghai Foursquare Indian restaurants link

sha_Ind_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=31.2322758,121.4692071&v=20210518&query=Indian Restaurant'
sha_Ind_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=31.2322758,121.4692071&v=20210518&query=Indian Restaurant'

# %%
# Shanghai Foursquare French restaurants link

sha_Fre_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=31.2322758,121.4692071&v=20210518&query=French Restaurant'
sha_Fre_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=31.2322758,121.4692071&v=20210518&query=French Restaurant'

# %%
# Shanghai Foursquare Japanese restaurants link

sha_Jap_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=31.2322758,121.4692071&v=20210518&query=Japanese Restaurant'
sha_Jap_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=31.2322758,121.4692071&v=20210518&query=Japanese Restaurant'

# %%
# Shanghai Foursquare Spanish restaurants link

sha_Spa_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=31.2322758,121.4692071&v=20210518&query=Spanish Restaurant'
sha_Spa_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=31.2322758,121.4692071&v=20210518&query=Spanish Restaurant'

# %%
# Shanghai Foursquare Chinese restaurants link

sha_Chi_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=31.2322758,121.4692071&v=20210518&query=Chinese Restaurant'
sha_Chi_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=31.2322758,121.4692071&v=20210518&query=Chinese Restaurant'

# %%
# Shanghai Foursquare Italian restaurants link

sha_Ita_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=31.2322758,121.4692071&v=20210518&query=Italian Restaurant'
sha_Ita_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=31.2322758,121.4692071&v=20210518&query=Italian Restaurant'

# %%
# Shanghai Indian restaurants raw data

sha_Ind_results = requests.get(sha_Ind_url).json()
sha_Ind_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4036da4e540652800fd68'},
#  'response': {'venues': [{'id': '501e4480e4b0724036bc2e7c',
#     'name': 'indian restaurant',
#     'location': {'lat': 31.221883238794426,
#      'lng': 121.4779731377388,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 31.221883238794426,
#        'lng': 121.4779731377388}],
#      'distance': 1426,
#      'cc': 'CN',
#      'city': 'Huangpu',
#      'state': '上海市',
#      'country': '中国',
#      'formattedAddress': ['Huangpu', '上海市', '中国']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621361517',
#     'hasPerk': False},
#    {'id': '5a62c86a666116710a38fc18',
#     'name': 'Nanak Indian Restaurant (娜娜可印度餐厅)',
# ...

# %%
# Shanghai French restaurants raw data

sha_Fre_results = requests.get(sha_Fre_url).json()
sha_Fre_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a40375bfd44c277fd627a8'},
#  'response': {'venues': [{'id': '540c4772498e8ef1a09c3981',
#     'name': 'Villandry French Restaurant',
#     'location': {'address': 'Nan Chang Lu',
#      'lat': 31.220913,
#      'lng': 121.464402,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 31.220913,
#        'lng': 121.464402}],
#      'distance': 1345,
#      'cc': 'CN',
#      'city': 'Huangpu',
#      'state': '上海市',
#      'country': '中国',
#      'formattedAddress': ['Nan Chang Lu', 'Huangpu', '上海市', '中国']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621361525',
#     'hasPerk': False},
#    {'id': '51fe4722498eb86acead686f',
# ...

# %%
# Shanghai Japanese restaurants raw data

sha_Jap_results = requests.get(sha_Jap_url).json()
sha_Jap_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4037cf4a25d2413e9489a'},
#  'response': {'venues': [{'id': '54abbde3498e6c2f6dc583e3',
#     'name': 'Takewaka Japanese Restaurant (金枪鱼)',
#     'location': {'lat': 31.238082,
#      'lng': 121.469205,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 31.238082,
#        'lng': 121.469205}],
#      'distance': 646,
#      'cc': 'CN',
#      'city': 'Huangpu',
#      'state': '上海市',
#      'country': '中国',
#      'formattedAddress': ['Huangpu', '上海市', '中国']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621361532',
#     'hasPerk': False},
#    {'id': '4cbd9032035d236a0d79eb4e',
#     'name': 'Fukui Japanese Restaurant (福井日本料理)',
# ...

# %%
# Shanghai Spanish restaurants raw data

sha_Spa_results = requests.get(sha_Spa_url).json()
sha_Spa_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a40388a1898d7946c0697f'},
#  'response': {'venues': [{'id': '502e436ae4b003c0ec03b892',
#     'name': 'Flamenco Spanish Restaurant',
#     'location': {'address': '22 Zhongshan E 2nd Rd',
#      'lat': 31.23269229088138,
#      'lng': 121.48927957071476,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 31.23269229088138,
#        'lng': 121.48927957071476}],
#      'distance': 1911,
#      'cc': 'CN',
#      'city': 'Huangpu',
#      'state': '上海市',
#      'country': '中国',
#      'formattedAddress': ['22 Zhongshan E 2nd Rd', 'Huangpu', '上海市', '中国']},
#     'categories': [{'id': '4bf58dd8d48988d150941735',
#       'name': 'Spanish Restaurant',
#       'pluralName': 'Spanish Restaurants',
#       'shortName': 'Spanish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621361544',
#     'hasPerk': False},
# ...

# %%
# Shanghai Chinese restaurants raw data

sha_Chi_results = requests.get(sha_Chi_url).json()
sha_Chi_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a40391df719f70b33fdc75'},
#  'response': {'venues': [{'id': '4b0588c2f964a52085d822e3',
#     'name': 'Ai Mei Chinese Restaurant (艾美轩)',
#     'location': {'address': '南京东路789号8F | 789 Nanjing Dong Lu',
#      'crossStreet': '上海皇家艾美酒店内',
#      'lat': 31.236211971449663,
#      'lng': 121.4706673383682,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 31.236211971449663,
#        'lng': 121.4706673383682}],
#      'distance': 459,
#      'postalCode': '200001',
#      'cc': 'CN',
#      'city': 'Huangpu',
#      'state': '上海市',
#      'country': '中国',
#      'formattedAddress': ['南京东路789号8F | 789 Nanjing Dong Lu (上海皇家艾美酒店内)',
#       'Huangpu',
#       '上海市, 200001',
#       '中国']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
# ...

# %%
# Shanghai Italian restaurants raw data

sha_Ita_results = requests.get(sha_Ita_url).json()
sha_Ita_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a40397a47f563dfad746cc'},
#  'response': {'venues': [{'id': '4c9f470519e4236a894d5789',
#     'name': 'Favola Italian Restaurant 法沃莱意大利餐厅',
#     'location': {'address': '789 East Nanjing Rd, 8F 南京东路789号8楼',
#      'crossStreet': 'Middle Xizang Rd 西藏中路',
#      'lat': 31.23579973511292,
#      'lng': 121.47102799281826,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 31.23579973511292,
#        'lng': 121.47102799281826}],
#      'distance': 428,
#      'postalCode': '200001',
#      'cc': 'CN',
#      'neighborhood': '黄埔',
#      'city': 'Huangpu',
#      'state': '上海市',
#      'country': '中国',
#      'formattedAddress': ['789 East Nanjing Rd, 8F 南京东路789号8楼 (Middle Xizang Rd 西藏中路), 黄埔',
#       'Huangpu',
#       '上海市, 200001',
#       '中国']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
# ...

# %%
# Shanghai Indian restaurants Dataframe

# assign relevant part of JSON to venues
sha_Ind_venues = sha_Ind_results['response']['venues']

# tranform venues into a dataframe
sha_Ind_dataframe = pd.json_normalize(sha_Ind_venues)
sha_Ind_dataframe.head()
# Out:
#                          id                               name  \
# 0  501e4480e4b0724036bc2e7c                  indian restaurant
# 1  5a62c86a666116710a38fc18  Nanak Indian Restaurant (娜娜可印度餐厅)
# 2  564577f238fa3af5a486eef2          Rangoli Indian Restaurant
# 3  5be15d7b6adbf5002ceca42f                  Indian Restaurant
# 4  4f12cb06e4b0aabf191dd2ad        Grand Taj Indian Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621361517    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621361517    False
# 2  [{'id': '54135bf5e4b08f3d2429dfdd', 'name': 'N...  v-1621361517    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621361517    False
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621361517    False
#
#    location.lat  location.lng  \
# 0     31.221883    121.477973
# 1     31.211198    121.398848
# 2     31.210387    121.463126
# ...

# %%
# Shanghai French restaurants Dataframe

# assign relevant part of JSON to venues
sha_Fre_venues = sha_Fre_results['response']['venues']

# tranform venues into a dataframe
sha_Fre_dataframe = pd.json_normalize(sha_Fre_venues)
sha_Fre_dataframe.head()
# Out:
#                          id                                     name  \
# 0  540c4772498e8ef1a09c3981              Villandry French Restaurant
# 1  51fe4722498eb86acead686f              Chez Ivan French Restaurant
# 2  4f87ba46e4b0b1c4ae2a3f50       雅笑亭 Teppan Yaki &French Restaurant
# 3  51456080e4b042f54732eabf                 Cujvre French Restaurant
# 4  4c5b9a3b7735c9b6d2418a72  French Visa Application Center | 法国签证中心
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621361525    False
# 1  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621361525    False
# 2  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621361525    False
# 3  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621361525    False
# 4  [{'id': '4bf58dd8d48988d12c951735', 'name': 'E...  v-1621361525    False
#
#   location.address  location.lat  location.lng  \
# ...

# %%
# Shanghai Japanese restaurants Dataframe

# assign relevant part of JSON to venues
sha_Jap_venues = sha_Jap_results['response']['venues']

# tranform venues into a dataframe
sha_Jap_dataframe = pd.json_normalize(sha_Jap_venues)
sha_Jap_dataframe.head()
# Out:
#                          id                                name  \
# 0  54abbde3498e6c2f6dc583e3  Takewaka Japanese Restaurant (金枪鱼)
# 1  4cbd9032035d236a0d79eb4e  Fukui Japanese Restaurant (福井日本料理)
# 2  4c31b57bed37a5935ab46a03     Edoya Japanese Restaurant (江戸家)
# 3  4dd7950fae60680f1509e6b8          Tetote Japanese Restaurant
# 4  4b5175b2f964a520b44d27e3           Itoya Japanese restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621361532    False
# 1  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1621361532    False
# 2  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621361532    False
# 3  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1621361532    False
# 4  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621361532    False
#
#    location.lat  location.lng  \
# 0     31.238082    121.469205
# 1     31.234410    121.479948
# ...

# %%
# Shanghai Spanish restaurants Dataframe

# assign relevant part of JSON to venues
sha_Spa_venues = sha_Spa_results['response']['venues']

# tranform venues into a dataframe
sha_Spa_dataframe = pd.json_normalize(sha_Spa_venues)
sha_Spa_dataframe.head()
# Out:
#                          id                                  name  \
# 0  502e436ae4b003c0ec03b892           Flamenco Spanish Restaurant
# 1  55f4f572498e9b20fa1e8abb             Albero Spanish Restaurant
# 2  4e5a1cc7b0fbdca30a06b610           Al Punto Spanish Restaurant
# 3  5da92ba435f0f90008764fcd  Spanish Chamber Of Commerce In China
# 4  4b0588c1f964a52020d822e3     ROOF 325 Rooftop Restaurant & Bar
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d150941735', 'name': 'S...  v-1621361544    False
# 1  [{'id': '4bf58dd8d48988d150941735', 'name': 'S...  v-1621361544    False
# 2  [{'id': '4bf58dd8d48988d14d941735', 'name': 'P...  v-1621361544    False
# 3  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1621361544    False
# 4  [{'id': '52e81612bcbc57f1066b79f9', 'name': 'M...  v-1621361544    False
#
#                                     location.address  location.lat  \
# ...

# %%
# Shanghai Chinese restaurants Dataframe

# assign relevant part of JSON to venues
sha_Chi_venues = sha_Chi_results['response']['venues']

# tranform venues into a dataframe
sha_Chi_dataframe = pd.json_normalize(sha_Chi_venues)
sha_Chi_dataframe.head()
# Out:
#                          id                                  name  \
# 0  4b0588c2f964a52085d822e3       Ai Mei Chinese Restaurant (艾美轩)
# 1  5dcb81eac05eac00084987e0  满宝楼 | Man Bao Lou Chinese Restaurant
# 2  5d1c89f07950f700234ecd79                    Chinese Restaurant
# 3  5131b4cfe4b0a0026f77b4df                Mao Chinese Restaurant
# 4  59be54512955130fbf38e694              Jinge Chinese Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1621361553    False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621361553    False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621361553    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621361553    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621361553    False
#
#                          location.address location.crossStreet  location.lat  \
# ...

# %%
# Shanghai Italian restaurants Dataframe

# assign relevant part of JSON to venues
sha_Ita_venues = sha_Ita_results['response']['venues']

# tranform venues into a dataframe
sha_Ita_dataframe = pd.json_normalize(sha_Ita_venues)
sha_Ita_dataframe.head()
# Out:
#                          id                                name  \
# 0  4c9f470519e4236a894d5789  Favola Italian Restaurant 法沃莱意大利餐厅
# 1  561e2e9f498eb3ef3a8af0b8             COME Italian restaurant
# 2  4e76de76c65bb91db4fd8b1c     Mari e Monti Italian Restaurant
# 3  4d29ab4c3c795481a5ccd99b            Isela Italian Restaurant
# 4  522071ba11d2fec7e7abff5e  Yuzu Italian Restaurant (欧风意酒家 柚子)
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621361559    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621361559    False
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621361559    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621361559    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621361559    False
#
#                      location.address   location.crossStreet  location.lat  \
# ...

# %%
# Shanghai filtered Indian restaurants list

# keep only columns that include venue name, and anything that is associated with location
sha_Ind_filtered_columns = ['name', 'categories'] + [col for col in sha_Ind_dataframe.columns if col.startswith('location.')] + ['id']
sha_Ind_dataframe_filtered = sha_Ind_dataframe.loc[:, sha_Ind_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        sha_Ind_categories_list = row['categories']
    except:
        sha_Ind_categories_list = row['venue.categories']
        
    if len(sha_Ind_categories_list) == 0:
        return None
    else:
        return sha_Ind_categories_list[0]['name']

# filter the category for each row
sha_Ind_dataframe_filtered['categories'] = sha_Ind_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
sha_Ind_dataframe_filtered.columns = [column.split('.')[-1] for column in sha_Ind_dataframe_filtered.columns]

sha_Ind_dataframe_filtered
# Out:
#                                      name                  categories  \
# 0                       indian restaurant           Indian Restaurant
# 1       Nanak Indian Restaurant (娜娜可印度餐厅)           Indian Restaurant
# 2               Rangoli Indian Restaurant     North Indian Restaurant
# 3                       Indian Restaurant           Indian Restaurant
# 4             Grand Taj Indian Restaurant           Indian Restaurant
# 5              Imperial Indian Restaurant           Indian Restaurant
# 6                Hazara Indian Restaurant           Indian Restaurant
# 7             Bollywood Indian Restaurant           Indian Restaurant
# 8            Ebeneezers Indian Restaurant           Indian Restaurant
# 9             Bollywood Indian Restaurant           Indian Restaurant
# 10      ROOF 325 Rooftop Restaurant & Bar  Modern European Restaurant
# 11      Chao Man Restaurant (潮民冰室) (潮民冰室)        Hong Kong Restaurant
# ...

# %%
# Shanghai filtered French restaurants list

# keep only columns that include venue name, and anything that is associated with location
sha_Fre_filtered_columns = ['name', 'categories'] + [col for col in sha_Fre_dataframe.columns if col.startswith('location.')] + ['id']
sha_Fre_dataframe_filtered = sha_Fre_dataframe.loc[:, sha_Fre_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        sha_Fre_categories_list = row['categories']
    except:
        sha_Fre_categories_list = row['venue.categories']
        
    if len(sha_Fre_categories_list) == 0:
        return None
    else:
        return sha_Fre_categories_list[0]['name']

# filter the category for each row
sha_Fre_dataframe_filtered['categories'] = sha_Fre_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
sha_Fre_dataframe_filtered.columns = [column.split('.')[-1] for column in sha_Fre_dataframe_filtered.columns]

sha_Fre_dataframe_filtered
# Out:
#                                             name                  categories  \
# 0                    Villandry French Restaurant           French Restaurant
# 1                    Chez Ivan French Restaurant           French Restaurant
# 2             雅笑亭 Teppan Yaki &French Restaurant         Japanese Restaurant
# 3                       Cujvre French Restaurant           French Restaurant
# 4        French Visa Application Center | 法国签证中心         Embassy / Consulate
# 5           L'Écailler French Seafood Restaurant           French Restaurant
# 6                                  French Bistro           French Restaurant
# 7                              French connection                 Bridal Shop
# 8              ROOF 325 Rooftop Restaurant & Bar  Modern European Restaurant
# 9   Former French Concession (French Concession)                Neighborhood
# 10            Favola Italian Restaurant 法沃莱意大利餐厅          Italian Restaurant
# ...

# %%
# Shanghai filtered Japanese restaurants list

# keep only columns that include venue name, and anything that is associated with location
sha_Jap_filtered_columns = ['name', 'categories'] + [col for col in sha_Jap_dataframe.columns if col.startswith('location.')] + ['id']
sha_Jap_dataframe_filtered = sha_Jap_dataframe.loc[:, sha_Jap_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        sha_Jap_categories_list = row['categories']
    except:
        sha_Jap_categories_list = row['venue.categories']
        
    if len(sha_Jap_categories_list) == 0:
        return None
    else:
        return sha_Jap_categories_list[0]['name']

# filter the category for each row
sha_Jap_dataframe_filtered['categories'] = sha_Jap_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
sha_Jap_dataframe_filtered.columns = [column.split('.')[-1] for column in sha_Jap_dataframe_filtered.columns]

sha_Jap_dataframe_filtered
# Out:
#                                                  name           categories  \
# 0                  Takewaka Japanese Restaurant (金枪鱼)  Japanese Restaurant
# 1                  Fukui Japanese Restaurant (福井日本料理)     Sushi Restaurant
# 2                     Edoya Japanese Restaurant (江戸家)  Japanese Restaurant
# 3                          Tetote Japanese Restaurant     Asian Restaurant
# 4                           Itoya Japanese restaurant  Japanese Restaurant
# 5   Manpuku Manzoku Japanese Restaurant 满腹满足 (offi...  Japanese Restaurant
# 6                 Manpuku-Manzoku Japanese Restaurant  Japanese Restaurant
# 7                        YOSHIZOH JAPANESE RESTAURANT  Japanese Restaurant
# 8                       Ooedo Japanese Restaurant 大江户  Japanese Restaurant
# 9                        Kakumaya Japanese Restaurant  Japanese Restaurant
# 10                         Yi Xiu Japanese Restaurant  Japanese Restaurant
# ...

# %%
# Shanghai filtered Spanish restaurants list

# keep only columns that include venue name, and anything that is associated with location
sha_Spa_filtered_columns = ['name', 'categories'] + [col for col in sha_Spa_dataframe.columns if col.startswith('location.')] + ['id']
sha_Spa_dataframe_filtered = sha_Spa_dataframe.loc[:, sha_Spa_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        sha_Spa_categories_list = row['categories']
    except:
        sha_Spa_categories_list = row['venue.categories']
        
    if len(sha_Spa_categories_list) == 0:
        return None
    else:
        return sha_Spa_categories_list[0]['name']

# filter the category for each row
sha_Spa_dataframe_filtered['categories'] = sha_Spa_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
sha_Spa_dataframe_filtered.columns = [column.split('.')[-1] for column in sha_Spa_dataframe_filtered.columns]

sha_Spa_dataframe_filtered
# Out:
#                                                  name  \
# 0                         Flamenco Spanish Restaurant
# 1                           Albero Spanish Restaurant
# 2                         Al Punto Spanish Restaurant
# 3                Spanish Chamber Of Commerce In China
# 4                   ROOF 325 Rooftop Restaurant & Bar
# 5                   Chao Man Restaurant (潮民冰室) (潮民冰室)
# 6                             Kungfu Restaurant (真功夫)
# 7                  Favola Italian Restaurant 法沃莱意大利餐厅
# 8                     Ai Mei Chinese Restaurant (艾美轩)
# 9                          TAI HING Restaurant (太兴餐厅)
# 10                            Kungfu Restaurant (真功夫)
# 11                              Qian Restaurant (黔香阁)
# 12                   ARK Restaurant & Lounge Bar (雅科)
# 13                            Sports Bar & Restaurant
# 14                 Takewaka Japanese Restaurant (金枪鱼)
# 15                         Xinwang Restaurant (新旺茶餐厅)
# ...

# %%
# Shanghai filtered Chinese restaurants list

# keep only columns that include venue name, and anything that is associated with location
sha_Chi_filtered_columns = ['name', 'categories'] + [col for col in sha_Chi_dataframe.columns if col.startswith('location.')] + ['id']
sha_Chi_dataframe_filtered = sha_Chi_dataframe.loc[:, sha_Chi_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        sha_Chi_categories_list = row['categories']
    except:
        sha_Chi_categories_list = row['venue.categories']
        
    if len(sha_Chi_categories_list) == 0:
        return None
    else:
        return sha_Chi_categories_list[0]['name']

# filter the category for each row
sha_Chi_dataframe_filtered['categories'] = sha_Chi_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
sha_Chi_dataframe_filtered.columns = [column.split('.')[-1] for column in sha_Chi_dataframe_filtered.columns]

sha_Chi_dataframe_filtered
# Out:
#                                                  name           categories  \
# 0                     Ai Mei Chinese Restaurant (艾美轩)   Dim Sum Restaurant
# 1                满宝楼 | Man Bao Lou Chinese Restaurant   Chinese Restaurant
# 2                                  Chinese Restaurant   Chinese Restaurant
# 3                              Mao Chinese Restaurant   Chinese Restaurant
# 4                            Jinge Chinese Restaurant   Chinese Restaurant
# 5                ZAO  ZI SHU VEGAN CHINESE RESTAURANT   Chinese Restaurant
# 6                      Another Chinese Restaurant 003   Chinese Restaurant
# 7                    御园中歺厅 Yu Yuan Chinese Restaurant   Dim Sum Restaurant
# 8                         Spectrum Chinese Restaurant   Chinese Restaurant
# 9               金凤楼 Golden Phoenix Chinese Restaurant   Chinese Restaurant
# 10  Nameless Hole In The Wall (literally) Chinese ...   Chinese Restaurant
# ...

# %%
# Shanghai filtered Italian restaurants list

# keep only columns that include venue name, and anything that is associated with location
sha_Ita_filtered_columns = ['name', 'categories'] + [col for col in sha_Ita_dataframe.columns if col.startswith('location.')] + ['id']
sha_Ita_dataframe_filtered = sha_Ita_dataframe.loc[:, sha_Ita_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        sha_Ita_categories_list = row['categories']
    except:
        sha_Ita_categories_list = row['venue.categories']
        
    if len(sha_Ita_categories_list) == 0:
        return None
    else:
        return sha_Ita_categories_list[0]['name']

# filter the category for each row
sha_Ita_dataframe_filtered['categories'] = sha_Ita_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
sha_Ita_dataframe_filtered.columns = [column.split('.')[-1] for column in sha_Ita_dataframe_filtered.columns]

sha_Ita_dataframe_filtered
# Out:
#                                         name                  categories  \
# 0         Favola Italian Restaurant 法沃莱意大利餐厅          Italian Restaurant
# 1                    COME Italian restaurant          Italian Restaurant
# 2            Mari e Monti Italian Restaurant          Italian Restaurant
# 3                   Isela Italian Restaurant          Italian Restaurant
# 4         Yuzu Italian Restaurant (欧风意酒家 柚子)          Italian Restaurant
# 5       French & Italian Restaurant (東郊賓館 周)           French Restaurant
# 6                   Isola Italian Restaurant          Italian Restaurant
# 7                   Bravo Italian Restaurant          Italian Restaurant
# 8               Danieli's Italian Restaurant          Italian Restaurant
# 9                    SEVE Italian Restaurant          Italian Restaurant
# 10      Marisa Italian Restaurant | 玛丽莎意大利餐厅          Italian Restaurant
# 11                 Jstone Italian Restaurant          Italian Restaurant
# ...

# %%
# Shanghai restaurants list
sha_dataframe_filt = (sha_Ind_dataframe_filtered, sha_Fre_dataframe_filtered, sha_Jap_dataframe_filtered, sha_Spa_dataframe_filtered, sha_Chi_dataframe_filtered, sha_Ita_dataframe_filtered)
sha_rest_filt = pd.concat(sha_dataframe_filt)
sha_rest_filt
# Out:
#                                  name                  categories        lat  \
# 0                   indian restaurant           Indian Restaurant  31.221883
# 1   Nanak Indian Restaurant (娜娜可印度餐厅)           Indian Restaurant  31.211198
# 2           Rangoli Indian Restaurant     North Indian Restaurant  31.210387
# 3                   Indian Restaurant           Indian Restaurant  31.233567
# 4         Grand Taj Indian Restaurant           Indian Restaurant  31.208580
# ..                                ...                         ...        ...
# 25  ROOF 325 Rooftop Restaurant & Bar  Modern European Restaurant  31.232848
# 26         Italian Kitchen by Seasalt          Italian Restaurant  31.217194
# 27  Chao Man Restaurant (潮民冰室) (潮民冰室)        Hong Kong Restaurant  31.226804
# 28  ORENO Dining Bar French + Italian          Italian Restaurant  31.223013
# 29            Kungfu Restaurant (真功夫)        Fast Food Restaurant  31.236265
#
# ...

# %%
# Paris location Co-ordinates

address = 'Paris'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 48.8566969 2.3514616

# %%
# Paris Foursquare Indian restaurants link

par_Ind_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=48.8566969,2.3514616&v=20210518&query=Indian Restaurant'
par_Ind_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=48.8566969,2.3514616&v=20210518&query=Indian Restaurant'

# %%
# Paris Foursquare French restaurants link

par_Fre_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=48.8566969,2.3514616&v=20210518&query=French Restaurant'
par_Fre_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=48.8566969,2.3514616&v=20210518&query=French Restaurant'

# %%
# Paris Foursquare Japanese restaurants link

par_Jap_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=48.8566969,2.3514616&v=20210518&query=Japanese Restaurant'
par_Jap_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=48.8566969,2.3514616&v=20210518&query=Japanese Restaurant'

# %%
# Paris Foursquare Spanish restaurants link

par_Spa_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=48.8566969,2.3514616&v=20210518&query=Spanish Restaurant'
par_Spa_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=48.8566969,2.3514616&v=20210518&query=Spanish Restaurant'

# %%
# Paris Foursquare Chinese restaurants link

par_Chi_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=48.8566969,2.3514616&v=20210518&query=Chinese Restaurant'
par_Chi_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=48.8566969,2.3514616&v=20210518&query=Chinese Restaurant'

# %%
# Paris Foursquare Italian restaurants link

par_Ita_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=48.8566969,2.3514616&v=20210518&query=Italian Restaurant'
par_Ita_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=48.8566969,2.3514616&v=20210518&query=Italian Restaurant'

# %%
# Paris Indian restaurants raw data

par_Ind_results = requests.get(par_Ind_url).json()
par_Ind_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4b58a5a12365733f1aca7'},
#  'response': {'venues': [{'id': '50ec1041e4b074765cac1058',
#     'name': 'Indian Restaurant',
#     'location': {'lat': 48.867077131499315,
#      'lng': 2.38603849125924,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.867077131499315,
#        'lng': 2.38603849125924}],
#      'distance': 2783,
#      'cc': 'FR',
#      'country': 'France',
#      'formattedAddress': ['France']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621407115',
#     'hasPerk': False},
#    {'id': '53cadb4e498e889ccf2f88ed',
#     'name': 'ganesh indian restaurant',
#     'location': {'address': '5 Rue Poirier De Narçay',
# ...

# %%
# Paris French restaurants raw data

par_Fre_results = requests.get(par_Fre_url).json()
par_Fre_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4b6d03c90d67684009cfe'},
#  'response': {'venues': [{'id': '5a4b619d911fc41c77fe6cbc',
#     'name': 'French Flair',
#     'location': {'lat': 48.85661400000001,
#      'lng': 2.3522219000000177,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85661400000001,
#        'lng': 2.3522219000000177}],
#      'distance': 56,
#      'postalCode': '75002',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['75002 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d105951735',
#       'name': 'Kids Store',
#       'pluralName': 'Kids Stores',
#       'shortName': 'Kids Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_kids_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621407440',
#     'hasPerk': False},
#    {'id': '55b122dd498e7e70c616cf67',
# ...

# %%
# Paris Japanese restaurants raw data

par_Jap_results = requests.get(par_Jap_url).json()
par_Jap_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4b6d725c9092a2f3fdcb6'},
#  'response': {'venues': [{'id': '4b86d6bff964a520c7a031e3',
#     'name': 'Ao Yama',
#     'location': {'address': '22 rue Verrerie',
#      'lat': 48.85739700909399,
#      'lng': 2.3545808047934327,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85739700909399,
#        'lng': 2.3545808047934327}],
#      'distance': 241,
#      'postalCode': '75004',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['22 rue Verrerie', '75004 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621407448',
#     'hasPerk': False},
# ...

# %%
# Paris Spanish restaurants raw data

par_Spa_results = requests.get(par_Spa_url).json()
par_Spa_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4b6eeadae6416c164ca9f'},
#  'response': {'venues': [{'id': '50263cdae4b098a561379a82',
#     'name': 'Restaurant Viet',
#     'location': {'address': 'Paris',
#      'lat': 48.85783124869833,
#      'lng': 2.351955093097346,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85783124869833,
#        'lng': 2.351955093097346}],
#      'distance': 131,
#      'cc': 'FR',
#      'country': 'France',
#      'formattedAddress': ['Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621407470',
#     'hasPerk': False},
#    {'id': '4f8e6f92e4b0cb228782dc5f',
#     'name': 'Restaurant Hotel Little Palace',
# ...

# %%
# Paris Chinese restaurants raw data

par_Chi_results = requests.get(par_Chi_url).json()
par_Chi_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4b6f6ba4a202f24e51086'},
#  'response': {'venues': [{'id': '563f567dcd10564a818b43a9',
#     'name': 'Chinese restaurant',
#     'location': {'lat': 48.865723,
#      'lng': 2.288941,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.865723,
#        'lng': 2.288941}],
#      'distance': 4687,
#      'cc': 'FR',
#      'country': 'France',
#      'formattedAddress': ['France']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621407478',
#     'hasPerk': False},
#    {'id': '55e81417498e41ba700ed8c1',
#     'name': 'Chinese Institute | Volta',
#     'location': {'address': '43 Rue Volta',
#      'lat': 48.866676330566406,
# ...

# %%
# Paris Italian restaurants raw data

par_Ita_results = requests.get(par_Ita_url).json()
par_Ita_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4b701b0448a58139d7612'},
#  'response': {'venues': [{'id': '509c35dce4b09c8921539b0a',
#     'name': 'Italian Bistro',
#     'location': {'lat': 48.86028222068349,
#      'lng': 2.354753889516401,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86028222068349,
#        'lng': 2.354753889516401}],
#      'distance': 466,
#      'cc': 'FR',
#      'country': 'France',
#      'formattedAddress': ['France']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621407489',
#     'hasPerk': False},
#    {'id': '4dc9246752b1b9daeb586b3f',
#     'name': 'Italian Corner',
#     'location': {'address': '14 rue Rambuteau',
#      'lat': 48.86048116546533,
# ...

# %%
# Paris Indian restaurants Dataframe

# assign relevant part of JSON to venues
par_Ind_venues = par_Ind_results['response']['venues']

# tranform venues into a dataframe
par_Ind_dataframe = pd.json_normalize(par_Ind_venues)
par_Ind_dataframe.head()
# Out:
#                          id                               name  \
# 0  50ec1041e4b074765cac1058                  Indian Restaurant
# 1  53cadb4e498e889ccf2f88ed           ganesh indian restaurant
# 2  577c2cc0498e5bb6ada3b31f  Indian Arapaana (Indian Aarapana)
# 3  4bae48c2f964a5202a9d3be3                       Indian Villa
# 4  5272c20411d2ce55ee988e5d                    Indian Heritage
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621407115    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621407115    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621407115    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621407115    False
# 4  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...  v-1621407115    False
#
#    location.lat  location.lng  \
# 0     48.867077      2.386038
# 1     48.881744      2.381374
# 2     48.852530      2.346471
# ...

# %%
# Paris French restaurants Dataframe

# assign relevant part of JSON to venues
par_Fre_venues = par_Fre_results['response']['venues']

# tranform venues into a dataframe
par_Fre_dataframe = pd.json_normalize(par_Fre_venues)
par_Fre_dataframe.head()
# Out:
#                          id                      name  \
# 0  5a4b619d911fc41c77fe6cbc              French Flair
# 1  55b122dd498e7e70c616cf67  French Paper Art Gallery
# 2  5b61d4a5396de0002c12b1ef        French Toast & Co.
# 3  5f646905213b273332ad8075       The French Bastards
# 4  5dbebf6700b2d60008740361             French Theory
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d105951735', 'name': 'K...  v-1621407440    False
# 1  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...  v-1621407440    False
# 2  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...  v-1621407440    False
# 3  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1621407440    False
# 4  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1621407440    False
#
#    location.lat  location.lng  \
# 0     48.856614      2.352222
# 1     48.867194      2.358324
# 2     48.844619      2.376266
# 3     48.865632      2.350492
# ...

# %%
# Paris Japanese restaurants Dataframe

# assign relevant part of JSON to venues
par_Jap_venues = par_Jap_results['response']['venues']

# tranform venues into a dataframe
par_Jap_dataframe = pd.json_normalize(par_Jap_venues)
par_Jap_dataframe.head()
# Out:
#                          id                            name  \
# 0  4b86d6bff964a520c7a031e3                         Ao Yama
# 1  589a0a35fc9b213d9bddd545          Japanese Knife Company
# 2  4b8813e4f964a5200ede31e3                 Japanese bistro
# 3  50263cdae4b098a561379a82                 Restaurant Viet
# 4  4f8e6f92e4b0cb228782dc5f  Restaurant Hotel Little Palace
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1621407448    False
# 1  [{'id': '4bf58dd8d48988d127951735', 'name': 'A...  v-1621407448    False
# 2  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1621407448    False
# 3  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...  v-1621407448    False
# 4  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1621407448    False
#
#       location.address  location.lat  location.lng  \
# 0      22 rue Verrerie     48.857397      2.354581
# ...

# %%
# Paris Spanish restaurants Dataframe

# assign relevant part of JSON to venues
par_Spa_venues = par_Spa_results['response']['venues']

# tranform venues into a dataframe
par_Spa_dataframe = pd.json_normalize(par_Spa_venues)
par_Spa_dataframe.head()
# Out:
#                          id                                name  \
# 0  50263cdae4b098a561379a82                     Restaurant Viet
# 1  4f8e6f92e4b0cb228782dc5f      Restaurant Hotel Little Palace
# 2  4e2b2d0ad22d3f83c88c7029            Le Restaurant des Poètes
# 3  50445ef7e4b0ba0a539ad83f  Restaurant Aux Tours de Notre-Dame
# 4  59ab059c86bc49021b313ca9             Restaurant Le Mona Lisa
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...  v-1621407470    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1621407470    False
# 2  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621407470    False
# 3  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621407470    False
# 4  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621407470    False
#
#       location.address  location.lat  location.lng  \
# 0                Paris     48.857831      2.351955
# ...

# %%
# Paris Chinese restaurants Dataframe

# assign relevant part of JSON to venues
par_Chi_venues = par_Chi_results['response']['venues']

# tranform venues into a dataframe
par_Chi_dataframe = pd.json_normalize(par_Chi_venues)
par_Chi_dataframe.head()
# Out:
#                          id  \
# 0  563f567dcd10564a818b43a9
# 1  55e81417498e41ba700ed8c1
# 2  5ae9799e6adbf5002c1e599f
# 3  4bc8431615a7ef3b49bb7ada
# 4  50263cdae4b098a561379a82
#
#                                                 name  \
# 0                                 Chinese restaurant
# 1                          Chinese Institute | Volta
# 2  Chinese Visa Application Service Center (Centr...
# 3                                            Asia 55
# 4                                    Restaurant Viet
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621407478    False
# 1  [{'id': '4bf58dd8d48988d1ae941735', 'name': 'U...  v-1621407478    False
# 2  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1621407478    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621407478    False
# 4  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...  v-1621407478    False
#
# ...

# %%
# Paris Italian restaurants Dataframe

# assign relevant part of JSON to venues
par_Ita_venues = par_Ita_results['response']['venues']

# tranform venues into a dataframe
par_Ita_dataframe = pd.json_normalize(par_Ita_venues)
par_Ita_dataframe.head()
# Out:
#                          id                            name  \
# 0  509c35dce4b09c8921539b0a                  Italian Bistro
# 1  4dc9246752b1b9daeb586b3f                  Italian Corner
# 2  4bfa23a98d30d13ab2410318              Italian Style Cafe
# 3  50263cdae4b098a561379a82                 Restaurant Viet
# 4  4f8e6f92e4b0cb228782dc5f  Restaurant Hotel Little Palace
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621407489    False
# 1  [{'id': '4bf58dd8d48988d1f5941735', 'name': 'G...  v-1621407489    False
# 2  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1621407489    False
# 3  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...  v-1621407489    False
# 4  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1621407489    False
#
#    location.lat  location.lng  \
# 0     48.860282      2.354754
# 1     48.860481      2.355675
# 2     48.860809      2.367785
# ...

# %%
# Paris filtered Indian restaurants list

# keep only columns that include venue name, and anything that is associated with location
par_Ind_filtered_columns = ['name', 'categories'] + [col for col in par_Ind_dataframe.columns if col.startswith('location.')] + ['id']
par_Ind_dataframe_filtered = par_Ind_dataframe.loc[:, par_Ind_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        par_Ind_categories_list = row['categories']
    except:
        par_Ind_categories_list = row['venue.categories']
        
    if len(par_Ind_categories_list) == 0:
        return None
    else:
        return par_Ind_categories_list[0]['name']

# filter the category for each row
par_Ind_dataframe_filtered['categories'] = par_Ind_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
par_Ind_dataframe_filtered.columns = [column.split('.')[-1] for column in par_Ind_dataframe_filtered.columns]

par_Ind_dataframe_filtered
# Out:
#                                          name                 categories  \
# 0                           Indian Restaurant          Indian Restaurant
# 1                    ganesh indian restaurant          Indian Restaurant
# 2           Indian Arapaana (Indian Aarapana)          Indian Restaurant
# 3                                Indian Villa          Indian Restaurant
# 4                             Indian Heritage                Art Gallery
# 5            Indian Motorcycle Paris Bastille            Motorcycle Shop
# 6                   Restaurant Indian Annachi          Indian Restaurant
# 7                                Indian Rocks                Men's Store
# 8                             Restaurant Viet      Vietnamese Restaurant
# 9                     Indian Motorcycle Store                       None
# 10             Restaurant Hotel Little Palace                 Restaurant
# 11                   Le Restaurant des Poètes          French Restaurant
# ...

# %%
# Paris filtered French restaurants list

# keep only columns that include venue name, and anything that is associated with location
par_Fre_filtered_columns = ['name', 'categories'] + [col for col in par_Fre_dataframe.columns if col.startswith('location.')] + ['id']
par_Fre_dataframe_filtered = par_Fre_dataframe.loc[:, par_Fre_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        par_Fre_categories_list = row['categories']
    except:
        par_Fre_categories_list = row['venue.categories']
        
    if len(par_Fre_categories_list) == 0:
        return None
    else:
        return par_Fre_categories_list[0]['name']

# filter the category for each row
par_Fre_dataframe_filtered['categories'] = par_Fre_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
par_Fre_dataframe_filtered.columns = [column.split('.')[-1] for column in par_Fre_dataframe_filtered.columns]

par_Fre_dataframe_filtered
# Out:
#                                   name               categories        lat  \
# 0                         French Flair               Kids Store  48.856614
# 1             French Paper Art Gallery              Art Gallery  48.867194
# 2                   French Toast & Co.           Sandwich Place  48.844619
# 3                  The French Bastards                   Bakery  48.865632
# 4                        French Theory              Coffee Shop  48.847903
# 5                       French Riviera             Cocktail Bar  48.861743
# 6                 La French - Nail Bar  Health & Beauty Service  48.844784
# 7                               French                     Park  48.864571
# 8                  French Californians                 Boutique  48.864771
# 9         Lermier Gourmet French Grill                BBQ Joint  48.851230
# 10                         French Food        French Restaurant  48.845168
# ...

# %%
# Paris filtered Japanese restaurants list

# keep only columns that include venue name, and anything that is associated with location
par_Jap_filtered_columns = ['name', 'categories'] + [col for col in par_Jap_dataframe.columns if col.startswith('location.')] + ['id']
par_Jap_dataframe_filtered = par_Jap_dataframe.loc[:, par_Jap_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        par_Jap_categories_list = row['categories']
    except:
        par_Jap_categories_list = row['venue.categories']
        
    if len(par_Jap_categories_list) == 0:
        return None
    else:
        return par_Jap_categories_list[0]['name']

# filter the category for each row
par_Jap_dataframe_filtered['categories'] = par_Jap_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
par_Jap_dataframe_filtered.columns = [column.split('.')[-1] for column in par_Jap_dataframe_filtered.columns]

par_Jap_dataframe_filtered
# Out:
#                                          name                 categories  \
# 0                                     Ao Yama           Sushi Restaurant
# 1                      Japanese Knife Company        Arts & Crafts Store
# 2                             Japanese bistro           Sushi Restaurant
# 3                             Restaurant Viet      Vietnamese Restaurant
# 4              Restaurant Hotel Little Palace                 Restaurant
# 5                    Le Restaurant des Poètes          French Restaurant
# 6          Restaurant Aux Tours de Notre-Dame          French Restaurant
# 7                     Restaurant Le Mona Lisa          French Restaurant
# 8          Jaja Restaurant 3 Rue Sainte-Croix                 Restaurant
# 9                  MIYAKADORI, Japanese store                   Boutique
# 10   Restaurant de l'Institut du Monde Arabe.  Middle Eastern Restaurant
# 11  Restaurant universitaire Crous de Censier          College Cafeteria
# ...

# %%
# Paris filtered Spanish restaurants list

# keep only columns that include venue name, and anything that is associated with location
par_Spa_filtered_columns = ['name', 'categories'] + [col for col in par_Spa_dataframe.columns if col.startswith('location.')] + ['id']
par_Spa_dataframe_filtered = par_Spa_dataframe.loc[:, par_Spa_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        par_Spa_categories_list = row['categories']
    except:
        par_Spa_categories_list = row['venue.categories']
        
    if len(par_Spa_categories_list) == 0:
        return None
    else:
        return par_Spa_categories_list[0]['name']

# filter the category for each row
par_Spa_dataframe_filtered['categories'] = par_Spa_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
par_Spa_dataframe_filtered.columns = [column.split('.')[-1] for column in par_Spa_dataframe_filtered.columns]

par_Spa_dataframe_filtered
# Out:
#                                                  name  \
# 0                                     Restaurant Viet
# 1                      Restaurant Hotel Little Palace
# 2                            Le Restaurant des Poètes
# 3                  Restaurant Aux Tours de Notre-Dame
# 4                             Restaurant Le Mona Lisa
# 5            Restaurant de l'Institut du Monde Arabe.
# 6           Restaurant universitaire Crous de Censier
# 7                     Nana - Restaurant - Paris 11ème
# 8                            Le Restaurant de L'Hôtel
# 9                          Restaurant du Montalembert
# 10                           Restaurant administratif
# 11                                Restaurant Istanbul
# 12                 Jaja Restaurant 3 Rue Sainte-Croix
# 13                                  Restaurant Deluxe
# 14                               Restaurant Istamboul
# 15                   Restaurant Cercle des Directeurs
# ...

# %%
# Paris filtered Chinese restaurants list

# keep only columns that include venue name, and anything that is associated with location
par_Chi_filtered_columns = ['name', 'categories'] + [col for col in par_Chi_dataframe.columns if col.startswith('location.')] + ['id']
par_Chi_dataframe_filtered = par_Chi_dataframe.loc[:, par_Chi_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        par_Chi_categories_list = row['categories']
    except:
        par_Chi_categories_list = row['venue.categories']
        
    if len(par_Chi_categories_list) == 0:
        return None
    else:
        return par_Chi_categories_list[0]['name']

# filter the category for each row
par_Chi_dataframe_filtered['categories'] = par_Chi_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
par_Chi_dataframe_filtered.columns = [column.split('.')[-1] for column in par_Chi_dataframe_filtered.columns]

par_Chi_dataframe_filtered
# Out:
#                                                  name  \
# 0                                  Chinese restaurant
# 1                           Chinese Institute | Volta
# 2   Chinese Visa Application Service Center (Centr...
# 3                                             Asia 55
# 4                                     Restaurant Viet
# 5                      Restaurant Hotel Little Palace
# 6                            Le Restaurant des Poètes
# 7                  Restaurant Aux Tours de Notre-Dame
# 8                             Restaurant Le Mona Lisa
# 9            Restaurant de l'Institut du Monde Arabe.
# 10          Restaurant universitaire Crous de Censier
# 11                    Nana - Restaurant - Paris 11ème
# 12                           Le Restaurant de L'Hôtel
# 13                         Restaurant du Montalembert
# 14                           Restaurant administratif
# 15                 Jaja Restaurant 3 Rue Sainte-Croix
# ...

# %%
# Paris filtered Italian restaurants list

# keep only columns that include venue name, and anything that is associated with location
par_Ita_filtered_columns = ['name', 'categories'] + [col for col in par_Ita_dataframe.columns if col.startswith('location.')] + ['id']
par_Ita_dataframe_filtered = par_Ita_dataframe.loc[:, par_Ita_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        par_Ita_categories_list = row['categories']
    except:
        par_Ita_categories_list = row['venue.categories']
        
    if len(par_Ita_categories_list) == 0:
        return None
    else:
        return par_Ita_categories_list[0]['name']

# filter the category for each row
par_Ita_dataframe_filtered['categories'] = par_Ita_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
par_Ita_dataframe_filtered.columns = [column.split('.')[-1] for column in par_Ita_dataframe_filtered.columns]

par_Ita_dataframe_filtered
# Out:
#                                                  name  \
# 0                                      Italian Bistro
# 1                                      Italian Corner
# 2                                  Italian Style Cafe
# 3                                     Restaurant Viet
# 4                      Restaurant Hotel Little Palace
# 5                            Le Restaurant des Poètes
# 6                  Restaurant Aux Tours de Notre-Dame
# 7                             Restaurant Le Mona Lisa
# 8                                   Italian Trattoria
# 9            Restaurant de l'Institut du Monde Arabe.
# 10          Restaurant universitaire Crous de Censier
# 11                    Nana - Restaurant - Paris 11ème
# 12                           Le Restaurant de L'Hôtel
# 13                         Restaurant du Montalembert
# 14                           Restaurant administratif
# 15                 Jaja Restaurant 3 Rue Sainte-Croix
# ...

# %%
# Paris restaurants list
par_dataframe_filt = (par_Ind_dataframe_filtered, par_Fre_dataframe_filtered, par_Jap_dataframe_filtered, par_Spa_dataframe_filtered, par_Chi_dataframe_filtered, par_Ita_dataframe_filtered)
par_rest_filt = pd.concat(par_dataframe_filt)
par_rest_filt
# Out:
#                                                  name           categories  \
# 0                                   Indian Restaurant    Indian Restaurant
# 1                            ganesh indian restaurant    Indian Restaurant
# 2                   Indian Arapaana (Indian Aarapana)    Indian Restaurant
# 3                                        Indian Villa    Indian Restaurant
# 4                                     Indian Heritage          Art Gallery
# ..                                                ...                  ...
# 25                                   Restaurant Au 35    French Restaurant
# 26                          Restaurant 't Nieuwe Kafe     Arepa Restaurant
# 27                            A Hot Pot Restaurant 一家  Szechuan Restaurant
# 28                        Restaurant Chez Le Libanais  Lebanese Restaurant
# 29  Restaurant de l'Hôtel Pullman Paris Centre - B...       Breakfast Spot
#
# ...

# %%
# Singapore location Co-ordinates

address = 'Singapore'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 1.357107 103.8194992

# %%
# Singapore Foursquare Indian restaurants link

sin_Ind_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=1.357107, 103.8194992&v=20210518&query=Indian Restaurant'
sin_Ind_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=1.357107, 103.8194992&v=20210518&query=Indian Restaurant'

# %%
# Singapore Foursquare French restaurants link

sin_Fre_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=1.357107, 103.8194992&v=20210518&query=French Restaurant'
sin_Fre_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=1.357107, 103.8194992&v=20210518&query=French Restaurant'

# %%
# Singapore Foursquare Japanese restaurants link

sin_Jap_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=1.357107, 103.8194992&v=20210518&query=Japanese Restaurant'
sin_Jap_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=1.357107, 103.8194992&v=20210518&query=Japanese Restaurant'

# %%
# Singapore# Singapore Foursquare Spanish restaurants link

sin_Spa_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=1.357107, 103.8194992&v=20210519&query=Spanish Restaurant'
sin_Spa_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=1.357107, 103.8194992&v=20210519&query=Spanish Restaurant'

# %%
# Singapore Foursquare Chinese restaurants link

sin_Chi_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=1.357107, 103.8194992&v=20210518&query=Chinese Restaurant'
sin_Chi_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=1.357107, 103.8194992&v=20210518&query=Chinese Restaurant'

# %%
# Singapore Foursquare Italian restaurants link
sin_Ita_url = 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=1.357107, 103.8194992&v=20210518&query=Italian Restaurant'
sin_Ita_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HYKDXJSCBGAQGJVGU0M3MPPMP2RXVH5XRUGW3KQ3QL4MXBRG&client_secret=ZOUY31JSYN1BSIQHD35SENWTSGXCNKCYJVSBG0NIEQIBKENN&ll=1.357107, 103.8194992&v=20210518&query=Italian Restaurant'

# %%
# Singapore Indian restaurants raw data

sin_Ind_results = requests.get(sin_Ind_url).json()
sin_Ind_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4ef92cd93772bb0001a3f'},
#  'response': {'venues': [{'id': '597412b1b2958f76696667cb',
#     'name': 'Chindamani Indian Restaurant Pte Ltd',
#     'location': {'address': 'Blk 121 Hougang Ave 1, #01-1346',
#      'lat': 1.353726,
#      'lng': 103.886923,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.353726,
#        'lng': 103.886923}],
#      'distance': 7512,
#      'postalCode': '530121',
#      'cc': 'SG',
#      'neighborhood': 'Hougang',
#      'state': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['Blk 121 Hougang Ave 1, #01-1346',
#       '530121',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
# ...

# %%
# Singapore French restaurants raw data

sin_Fre_results = requests.get(sin_Fre_url).json()
sin_Fre_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4ef9dc3c91a0291078b7b'},
#  'response': {'venues': [{'id': '4d2705c86e27a143ffc80a24',
#     'name': 'Abisinthe French Restaurant',
#     'location': {'lat': 1.2905959163800502,
#      'lng': 103.83546950763534,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.2905959163800502,
#        'lng': 103.83546950763534}],
#      'distance': 7614,
#      'cc': 'SG',
#      'country': 'Singapore',
#      'formattedAddress': ['Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621421981',
#     'hasPerk': False},
#    {'id': '4e1fc00efa761d67106b4d4c',
#     'name': 'Silk Restaurant',
#     'location': {'address': 'Singapore Island Country Club',
# ...

# %%
# Singapore Japanese restaurants raw data

sin_Jap_results = requests.get(sin_Jap_url).json()
sin_Jap_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4efa7adae6416c1d4e6cc'},
#  'response': {'venues': [{'id': '4bbdbb53f57ba593c459aeb9',
#     'name': 'Tomoe Japanese Restaurant',
#     'location': {'address': 'Upper Thomson',
#      'crossStreet': 'Upper Thomson Road',
#      'lat': 1.3536486597386679,
#      'lng': 103.83357894937039,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3536486597386679,
#        'lng': 103.83357894937039}],
#      'distance': 1613,
#      'postalCode': '574390',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['Upper Thomson (Upper Thomson Road)',
#       '574390',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
# ...

# %%
# Singapore Spanish restaurants raw data

sin_Spa_results = requests.get(sin_Spa_url).json()
sin_Spa_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4efb2801445385cd06928'},
#  'response': {'venues': [{'id': '4c9585ee38dd8cfa19ecd362',
#     'name': 'Don Quijote Spanish Restaurant',
#     'location': {'address': '7th Mile Coffeeshop',
#      'crossStreet': '18 Toh Yi Drive',
#      'lat': 1.339989,
#      'lng': 103.77279,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.339989,
#        'lng': 103.77279}],
#      'distance': 5536,
#      'postalCode': '590018',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['7th Mile Coffeeshop (18 Toh Yi Drive)',
#       '590018',
#       'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d150941735',
#       'name': 'Spanish Restaurant',
#       'pluralName': 'Spanish Restaurants',
#       'shortName': 'Spanish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#        'suffix': '.png'},
#       'primary': True}],
# ...

# %%
# Singapore Chinese restaurants raw data

sin_Chi_results = requests.get(sin_Chi_url).json()
sin_Chi_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4efbfadae6416c1d51c4d'},
#  'response': {'venues': [{'id': '4c6165973986e21ea472964f',
#     'name': 'Dong Fang Mei Shi Fan Dian 东方美食饭店 (Oriental Chinese Restaurant)',
#     'location': {'address': '195 New Bridge Road',
#      'lat': 1.2842092393289395,
#      'lng': 103.84368538856506,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.2842092393289395,
#        'lng': 103.84368538856506}],
#      'distance': 8549,
#      'postalCode': '059425',
#      'cc': 'SG',
#      'neighborhood': 'Chinatown',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['195 New Bridge Road', '059425', 'Singapore']},
#     'categories': [{'id': '52af3a9f3cf9994f4e043bef',
#       'name': 'Dongbei Restaurant',
#       'pluralName': 'Dongbei Restaurants',
#       'shortName': 'Dongbei',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
# ...

# %%
# Singapore Italian restaurants raw data

sin_Ita_results = requests.get(sin_Ita_url).json()
sin_Ita_results
# Out:
# {'meta': {'code': 200, 'requestId': '60a4efca013f2320afb4011b'},
#  'response': {'venues': [{'id': '4bdbe34963c5c9b6fded2968',
#     'name': 'Etna Italian Restaurant',
#     'location': {'address': '110 Upper East Coast Road',
#      'lat': 1.3134023874385283,
#      'lng': 103.92928305781336,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3134023874385283,
#        'lng': 103.92928305781336}],
#      'distance': 13150,
#      'postalCode': '455298',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['110 Upper East Coast Road', '455298', 'Singapore']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621422026',
# ...

# %%
# Singapore Indian restaurants Dataframe

# assign relevant part of JSON to venues
sin_Ind_venues = sin_Ind_results['response']['venues']

# tranform venues into a dataframe
sin_Ind_dataframe = pd.json_normalize(sin_Ind_venues)
sin_Ind_dataframe.head()
# Out:
#                          id                                    name  \
# 0  597412b1b2958f76696667cb    Chindamani Indian Restaurant Pte Ltd
# 1  4b058812f964a520deaf22e3  Shahi Maharani North Indian Restaurant
# 2  50948dc0e4b0836530a736a5           Sakunthalas Indian Restaurant
# 3  4cb7db7e035d236a2dd8c84e               Phoenix Indian Restaurant
# 4  5af993b22aff31002ceff85d              Shamiana Indian Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621421970    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621421970    False
# 2                                                 []  v-1621421970    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621421970    False
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1621421970    False
#
#                        location.address  location.lat  location.lng  \
# ...

# %%
# Singapore French restaurants Dataframe

# assign relevant part of JSON to venues
sin_Fre_venues = sin_Fre_results['response']['venues']

# tranform venues into a dataframe
sin_Fre_dataframe = pd.json_normalize(sin_Fre_venues)
sin_Fre_dataframe.head()
# Out:
#                          id                          name  \
# 0  4d2705c86e27a143ffc80a24   Abisinthe French Restaurant
# 1  4e1fc00efa761d67106b4d4c               Silk Restaurant
# 2  4d536aa22e336a3157592eeb  French Toast Language Centre
# 3  4b07e7b0f964a520fb0023e3              ATOUT Restaurant
# 4  5317fef7498e74c38c88d165                 French Bistro
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621421981    False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621421981    False
# 2  [{'id': '4bf58dd8d48988d1ab941735', 'name': 'S...  v-1621421981    False
# 3  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621421981    False
# 4  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1621421981    False
#
#    location.lat  location.lng  \
# 0      1.290596    103.835470
# 1      1.359086    103.818634
# 2      1.352835    103.835394
# ...

# %%
# Singapore Japanese restaurants Dataframe

# assign relevant part of JSON to venues
sin_Jap_venues = sin_Jap_results['response']['venues']

# tranform venues into a dataframe
sin_Jap_dataframe = pd.json_normalize(sin_Jap_venues)
sin_Jap_dataframe.head()
# Out:
#                          id                               name  \
# 0  4bbdbb53f57ba593c459aeb9          Tomoe Japanese Restaurant
# 1  4b3d8043f964a520f29425e3       Shin Yuu Japanese Restaurant
# 2  4c079d410ed3c9286abe797d      Nanbantei Japanese Restaurant
# 3  4ee9eb140e61f09a661497d2  博多もつ鍋 悟喰 Japanese Restaurant Goku
# 4  5b2a4bf67e4b4e0024a1a147         Maneko Japanese Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621421991    False
# 1  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621421991    False
# 2  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621421991    False
# 3  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621421991    False
# 4  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1621421991    False
#
#            location.address location.crossStreet  location.lat  location.lng  \
# ...

# %%
# Singapore Spanish restaurants Dataframe

# assign relevant part of JSON to venues
sin_Spa_venues = sin_Spa_results['response']['venues']

# tranform venues into a dataframe
sin_Spa_dataframe = pd.json_normalize(sin_Spa_venues)
sin_Spa_dataframe.head()
# Out:
#                          id                            name  \
# 0  4c9585ee38dd8cfa19ecd362  Don Quijote Spanish Restaurant
# 1  51bc6530498ee5621f999822     Serenity Spanish Restaurant
# 2  604204ad97ed220dcc432775        Kluto Spanish Restaurant
# 3  4e7ed2e8e5fadc8374d439a9        GjB's Spanish Restaurant
# 4  506e5ef1e4b06a580b065adc     Binomio Spanish Restaurante
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d150941735', 'name': 'S...  v-1621422002    False
# 1  [{'id': '4bf58dd8d48988d150941735', 'name': 'S...  v-1621422002    False
# 2  [{'id': '4bf58dd8d48988d1f5941735', 'name': 'G...  v-1621422002    False
# 3  [{'id': '4bf58dd8d48988d150941735', 'name': 'S...  v-1621422002    False
# 4  [{'id': '4bf58dd8d48988d150941735', 'name': 'S...  v-1621422002    False
#
#                            location.address location.crossStreet  \
# 0                       7th Mile Coffeeshop      18 Toh Yi Drive
# ...

# %%
# Singapore Chinese restaurants Dataframe

# assign relevant part of JSON to venues
sin_Chi_venues = sin_Chi_results['response']['venues']

# tranform venues into a dataframe
sin_Chi_dataframe = pd.json_normalize(sin_Chi_venues)
sin_Chi_dataframe.head()
# Out:
#                          id  \
# 0  4c6165973986e21ea472964f
# 1  4d47e3af847e6dcb176398c4
# 2  4d1eb3ed16cfb60c807e4b61
# 3  4bab5c81f964a52061a33ae3
# 4  4daac6cfcda1652a2b943b71
#
#                                                 name  \
# 0  Dong Fang Mei Shi Fan Dian 东方美食饭店 (Oriental Ch...
# 1                         Wan Hao Chinese Restaurant
# 2                             The Chinese Restaurant
# 3            Guan Kitchen Chinese Restaurant 壮元府传统美食
# 4               Yang Gui Fei Chinese Restaurant  羊貴妃
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '52af3a9f3cf9994f4e043bef', 'name': 'D...  v-1621422015    False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621422015    False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621422015    False
# 3  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1621422015    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1621422015    False
#
# ...

# %%
# Singapore Italian restaurants Dataframe

# assign relevant part of JSON to venues
sin_Ita_venues = sin_Ita_results['response']['venues']

# tranform venues into a dataframe
sin_Ita_dataframe = pd.json_normalize(sin_Ita_venues)
sin_Ita_dataframe.head()
# Out:
#                          id                                name  \
# 0  4bdbe34963c5c9b6fded2968             Etna Italian Restaurant
# 1  4db253294df053200616fe76        Rosmarino Italian Restaurant
# 2  552a6c08498e4c2b6e6d8fa7           Cucina Italian Restaurant
# 3  543bc4d1498e0fa6d2596641      Salvo Italian Restaurant & Bar
# 4  4d1331fa9844b60c84d7c0d4  Etna Italian Restaurant & Pizzeria
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621422026    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621422026    False
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621422026    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621422026    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1621422026    False
#
#             location.address  location.lat  location.lng  \
# 0  110 Upper East Coast Road      1.313402    103.929283
# ...

# %%
# Singapore filtered Indian restaurants list

# keep only columns that include venue name, and anything that is associated with location
sin_Ind_filtered_columns = ['name', 'categories'] + [col for col in sin_Ind_dataframe.columns if col.startswith('location.')] + ['id']
sin_Ind_dataframe_filtered = sin_Ind_dataframe.loc[:, sin_Ind_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        sin_Ind_categories_list = row['categories']
    except:
        sin_Ind_categories_list = row['venue.categories']
        
    if len(sin_Ind_categories_list) == 0:
        return None
    else:
        return sin_Ind_categories_list[0]['name']

# filter the category for each row
sin_Ind_dataframe_filtered['categories'] = sin_Ind_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
sin_Ind_dataframe_filtered.columns = [column.split('.')[-1] for column in sin_Ind_dataframe_filtered.columns]

sin_Ind_dataframe_filtered
# Out:
#                                           name               categories  \
# 0         Chindamani Indian Restaurant Pte Ltd        Indian Restaurant
# 1       Shahi Maharani North Indian Restaurant        Indian Restaurant
# 2                Sakunthalas Indian Restaurant                     None
# 3                    Phoenix Indian Restaurant        Indian Restaurant
# 4                   Shamiana Indian Restaurant        Indian Restaurant
# 5        Swadhisht Authentic Indian Restaurant        Indian Restaurant
# 6                Univer Cell Indian Restaurant  South Indian Restaurant
# 7                   Komala's-Indian Restaurant        Indian Restaurant
# 8     Ashoka Tandoor - North Indian Restaurant        Indian Restaurant
# 9                Handi North Indian Restaurant        Indian Restaurant
# 10                    Fatima Indian Restaurant        Indian Restaurant
# 11           Dickson's North Indian Restaurant                     None
# ...

# %%
# Delhi filtered French restaurants list

# keep only columns that include venue name, and anything that is associated with location
sin_Fre_filtered_columns = ['name', 'categories'] + [col for col in sin_Fre_dataframe.columns if col.startswith('location.')] + ['id']
sin_Fre_dataframe_filtered = sin_Fre_dataframe.loc[:, sin_Fre_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        sin_Fre_categories_list = row['categories']
    except:
        sin_Fre_categories_list = row['venue.categories']
        
    if len(sin_Fre_categories_list) == 0:
        return None
    else:
        return sin_Fre_categories_list[0]['name']

# filter the category for each row
sin_Fre_dataframe_filtered['categories'] = sin_Fre_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
sin_Fre_dataframe_filtered.columns = [column.split('.')[-1] for column in sin_Fre_dataframe_filtered.columns]

sin_Fre_dataframe_filtered
# Out:
#                                                  name           categories  \
# 0                         Abisinthe French Restaurant    French Restaurant
# 1                                     Silk Restaurant   Chinese Restaurant
# 2                        French Toast Language Centre       Student Center
# 3                                    ATOUT Restaurant    French Restaurant
# 4                                       French Bistro    French Restaurant
# 5                         Saybons French Food Factory    French Restaurant
# 6                                 Hong Wen Restaurant                 None
# 7                                         French Road                 Road
# 8                       French Faster Language School       Student Center
# 9                              French Bridal Boutique          Bridal Shop
# 10                       The French Stall @MacPherson    French Restaurant
# ...

# %%
# Singapore filtered Japanese restaurants list

# keep only columns that include venue name, and anything that is associated with location
sin_Jap_filtered_columns = ['name', 'categories'] + [col for col in sin_Jap_dataframe.columns if col.startswith('location.')] + ['id']
sin_Jap_dataframe_filtered = sin_Jap_dataframe.loc[:, sin_Jap_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        sin_Jap_categories_list = row['categories']
    except:
        sin_Jap_categories_list = row['venue.categories']
        
    if len(sin_Jap_categories_list) == 0:
        return None
    else:
        return sin_Jap_categories_list[0]['name']

# filter the category for each row
sin_Jap_dataframe_filtered['categories'] = sin_Jap_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
sin_Jap_dataframe_filtered.columns = [column.split('.')[-1] for column in sin_Jap_dataframe_filtered.columns]

sin_Jap_dataframe_filtered
# Out:
#                                          name           categories  \
# 0                   Tomoe Japanese Restaurant  Japanese Restaurant
# 1                Shin Yuu Japanese Restaurant  Japanese Restaurant
# 2               Nanbantei Japanese Restaurant  Japanese Restaurant
# 3           博多もつ鍋 悟喰 Japanese Restaurant Goku  Japanese Restaurant
# 4                  Maneko Japanese Restaurant  Japanese Restaurant
# 5        Yamagawa Japanese Restaurant Pte Ltd     Sushi Restaurant
# 6                     Miz Japanese Restaurant  Japanese Restaurant
# 7                    Suju Japanese Restaurant  Japanese Restaurant
# 8                 Tatsuya Japanese Restaurant  Japanese Restaurant
# 9                Bachmann Japanese Restaurant  Japanese Restaurant
# 10                   Ikoi Japanese Restaurant     Sushi Restaurant
# 11                Irodori Japanese Restaurant  Japanese Restaurant
# 12               Furusato Japanese Restaurant  Japanese Restaurant
# ...

# %%
# Spanish filtered Spanish restaurants list

# keep only columns that include venue name, and anything that is associated with location
sin_Spa_filtered_columns = ['name', 'categories'] + [col for col in sin_Spa_dataframe.columns if col.startswith('location.')] + ['id']
sin_Spa_dataframe_filtered = sin_Spa_dataframe.loc[:, sin_Spa_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        sin_Spa_categories_list = row['categories']
    except:
        sin_Spa_categories_list = row['venue.categories']
        
    if len(sin_Spa_categories_list) == 0:
        return None
    else:
        return sin_Spa_categories_list[0]['name']

# filter the category for each row
sin_Spa_dataframe_filtered['categories'] = sin_Spa_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
sin_Spa_dataframe_filtered.columns = [column.split('.')[-1] for column in sin_Spa_dataframe_filtered.columns]

sin_Spa_dataframe_filtered
# Out:
#                                                  name  \
# 0                      Don Quijote Spanish Restaurant
# 1                         Serenity Spanish Restaurant
# 2                            Kluto Spanish Restaurant
# 3                            GjB's Spanish Restaurant
# 4                         Binomio Spanish Restaurante
# 5                                     Silk Restaurant
# 6                                     Spanish Village
# 7                             My Little Spanish Place
# 8                                 Hong Wen Restaurant
# 9                          Casuarina Curry Restaurant
# 10                    Nam Kee Chicken Rice Restaurant
# 11                           Parker Korean Restaurant
# 12                        Restaurant Iskander Pte Ltd
# 13                            Plum Village Restaurant
# 14            Mapo Doufu Restaurant / T-One Steamboat
# 15                                Lek Chew Restaurant
# ...

# %%
# Spanish filtered Chinese restaurants list

# keep only columns that include venue name, and anything that is associated with location
sin_Chi_filtered_columns = ['name', 'categories'] + [col for col in sin_Chi_dataframe.columns if col.startswith('location.')] + ['id']
sin_Chi_dataframe_filtered = sin_Chi_dataframe.loc[:, sin_Chi_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        sin_Chi_categories_list = row['categories']
    except:
        sin_Chi_categories_list = row['venue.categories']
        
    if len(sin_Chi_categories_list) == 0:
        return None
    else:
        return sin_Chi_categories_list[0]['name']

# filter the category for each row
sin_Chi_dataframe_filtered['categories'] = sin_Chi_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
sin_Chi_dataframe_filtered.columns = [column.split('.')[-1] for column in sin_Chi_dataframe_filtered.columns]

sin_Chi_dataframe_filtered
# Out:
#                                                  name           categories  \
# 0   Dong Fang Mei Shi Fan Dian 东方美食饭店 (Oriental Ch...   Dongbei Restaurant
# 1                          Wan Hao Chinese Restaurant   Chinese Restaurant
# 2                              The Chinese Restaurant   Chinese Restaurant
# 3             Guan Kitchen Chinese Restaurant 壮元府传统美食     Asian Restaurant
# 4                Yang Gui Fei Chinese Restaurant  羊貴妃   Chinese Restaurant
# 5                     Chinese Restaurant (Jia Jia Le)          Coffee Shop
# 6      Berjaya Waterfront Hotel Chinese Restaurant 聚轩   Chinese Restaurant
# 7                     River Palace Chinese Restaurant   Chinese Restaurant
# 8                      Kai Xuan Chinese Restaurant 凯旋   Chinese Restaurant
# 9                    East Treasure Chinese Restaurant   Chinese Restaurant
# 10                          Korean Chinese Restaurant    Korean Restaurant
# ...

# %%
# Spanish filtered Iyalian restaurants list

# keep only columns that include venue name, and anything that is associated with location
sin_Ita_filtered_columns = ['name', 'categories'] + [col for col in sin_Ita_dataframe.columns if col.startswith('location.')] + ['id']
sin_Ita_dataframe_filtered = sin_Ita_dataframe.loc[:, sin_Ita_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        sin_Ita_categories_list = row['categories']
    except:
        sin_Ita_categories_list = row['venue.categories']
        
    if len(sin_Ita_categories_list) == 0:
        return None
    else:
        return sin_Ita_categories_list[0]['name']

# filter the category for each row
sin_Ita_dataframe_filtered['categories'] = sin_Ita_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
sin_Ita_dataframe_filtered.columns = [column.split('.')[-1] for column in sin_Ita_dataframe_filtered.columns]

sin_Ita_dataframe_filtered
# Out:
#                                                  name          categories  \
# 0                             Etna Italian Restaurant  Italian Restaurant
# 1                        Rosmarino Italian Restaurant  Italian Restaurant
# 2                           Cucina Italian Restaurant  Italian Restaurant
# 3                      Salvo Italian Restaurant & Bar  Italian Restaurant
# 4                  Etna Italian Restaurant & Pizzeria  Italian Restaurant
# 5                           Follia Italian Restaurant  Italian Restaurant
# 6                          Da Luca Italian Restaurant  Italian Restaurant
# 7                  Garibaldi Italian Restaurant & Bar  Italian Restaurant
# 8                      Buona Terra Italian Restaurant  Italian Restaurant
# 9                      Porta Porta Italian Restaurant  Italian Restaurant
# 10  Mangiamo Pizzeria (fka Persepolis Italian Rest...  Italian Restaurant
# 11                           Mezza Italian Restaurant  Italian Restaurant
# ...

# %%
# Singapore restaurants list
sin_dataframe_filt = (sin_Ind_dataframe_filtered, sin_Fre_dataframe_filtered, sin_Jap_dataframe_filtered, sin_Spa_dataframe_filtered, sin_Chi_dataframe_filtered, sin_Ita_dataframe_filtered)
sin_rest_filt = pd.concat(sin_dataframe_filt)
sin_rest_filt
# Out:
#                                        name          categories  \
# 0      Chindamani Indian Restaurant Pte Ltd   Indian Restaurant
# 1    Shahi Maharani North Indian Restaurant   Indian Restaurant
# 2             Sakunthalas Indian Restaurant                None
# 3                 Phoenix Indian Restaurant   Indian Restaurant
# 4                Shamiana Indian Restaurant   Indian Restaurant
# ..                                      ...                 ...
# 25                   Italian Ice Cream Cafe        Dessert Shop
# 26                  Plum Village Restaurant  Chinese Restaurant
# 27                    Al Forno's Restaurant  Italian Restaurant
# 28              Restaurant Iskander Pte Ltd   Indian Restaurant
# 29  Mapo Doufu Restaurant / T-One Steamboat  Chinese Restaurant
#
#                                  address       lat         lng  \
# 0        Blk 121 Hougang Ave 1, #01-1346  1.353726  103.886923
# 1   #03-21B Raffles City Shopping Centre  1.294389  103.853872
# ...
